# %% [markdown]
# # This is the driver file for the full pseudo transcript, TF-IDF based subset selection experiment

# %% [markdown]
# ### Creating pseudo transcripts

# %%
import sys
import torch

# %%
print(sys.executable)
# Out:
# /home/mayank/.conda/envs/error/bin/python

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
BASE_PATH = '/home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization'
CURR_DIR = BASE_PATH + '/entropy-testing/pseudo-transcript-entropy'
PARENT_DIR = BASE_PATH + '/entropy-testing'

# %%
ACCENTS = list(map(lambda x : x + '_english', [
    'assamese_female', 
    'gujarati_female',
    'hindi_male',
    'kannada_male',
    'malayalam_male',
    'manipuri_female',
    'rajasthani_male',
    'tamil_male'
]))

BUDGETS= [
    '100',
    '200',
    '400',
    '800'
]

TARGET = [10]

METHODS = ['FL2MI', 'GCMI', 'LogDMI']

ETA = ['1.0']

SIM = ['euclidean']

FEATURES = ['39']

RUNS = ['1', '2', '3']

# %%
# Do the SMI generation

def doSMI(feature, similarity, eta, target, budget, method, accent):
    
    python_file = CURR_DIR + "/TSS.py"
    
    print("----------------------- TSS -----------------------")
    print(f"accent_{accent}, budget_{budget}, method_{method}")
    # !$sys.executable $python_file --target $target --budget $budget --similarity $similarity --eta $eta --accent $accent --fxn $method --feature_type $feature
    

def generate_SMI_selections():
    for feature in FEATURES:
        for sim in SIM:
            for eta in ETA:
                for target in TARGET:
                    for budget in BUDGETS:
                        for method in METHODS:
                            for accent in ACCENTS:
                                doSMI(
                                    feature = feature,
                                    similarity = sim,
                                    eta = eta,
                                    target = target,
                                    budget = budget,
                                    method = method,
                                    accent = accent
                                )

generate_SMI_selections()
# Out:
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_100, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 13.553933143615723s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_100, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 14.332338333129883s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_100, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.744808435440063s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_100, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 14.861085891723633s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_100, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.412113428115845s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_100, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 13.576459884643555s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_100, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 14.41048812866211s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_100, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 14.821863889694214s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_100, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 14.690638542175293s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_100, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 14.464845657348633s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_100, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.927768230438232s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_100, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 14.560079336166382s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_100, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.472135066986084s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_100, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 13.197418451309204s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_100, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 14.561116456985474s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_100, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 14.430572271347046s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_100, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 14.390303373336792s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_100, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 14.377004623413086s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_100, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.356721639633179s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_100, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 14.198881387710571s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_100, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.536850214004517s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_100, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 14.332736492156982s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_100, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 14.255072355270386s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_100, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 14.70552659034729s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 300 of 300]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_200, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 14.6485276222229s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_200, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 14.142468452453613s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_200, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.64233684539795s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_200, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 14.45015025138855s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_200, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.636475324630737s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_200, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 14.913573741912842s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_200, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 14.433278799057007s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_200, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 14.450048923492432s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_200, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 14.468450546264648s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_200, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 14.536394357681274s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_200, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.85579800605774s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]||||||||||||||||   ]87% [Iteration 522 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_200, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 13.604217052459717s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_200, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.48925256729126s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_200, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 15.016693830490112s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_200, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 14.90489149093628s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_200, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 14.489739894866943s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_200, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 14.30910325050354s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_200, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 14.089555501937866s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_200, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.192578792572021s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_200, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 14.366676092147827s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_200, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.081899404525757s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_200, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 14.172267436981201s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_200, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 14.16883134841919s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_200, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 14.299329042434692s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 600 of 600]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_400, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 14.023348093032837s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_400, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 14.708475112915039s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_400, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.467679262161255s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_400, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 14.065593004226685s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_400, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.465477228164673s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_400, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 14.267688751220703s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_400, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 13.941843032836914s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_400, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 14.768436670303345s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_400, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 14.484121084213257s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_400, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 13.943597078323364s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_400, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.552203178405762s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]ation 552 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_400, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 14.619750261306763s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_400, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.740570306777954s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_400, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 14.501962900161743s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_400, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 14.388112306594849s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_400, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 14.326535701751709s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_400, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 14.372950315475464s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_400, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 14.048982620239258s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_400, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.373422384262085s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_400, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 13.187770128250122s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_400, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.184417486190796s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_400, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 14.268606185913086s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_400, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 14.468360900878906s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_400, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 14.3831148147583s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 1200 of 1200]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_800, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 14.496518850326538s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_800, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 14.623881578445435s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_800, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.363070011138916s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_800, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 13.31873607635498s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_800, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.085252523422241s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_800, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 14.53728437423706s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_800, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 14.627792358398438s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_800, method_FL2MI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 13.390913486480713s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating FL2MI object
#
#
# FL2MI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_800, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 14.673938751220703s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_800, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 14.444024562835693s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_800, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.706544876098633s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_800, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 14.42125129699707s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_800, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.483789920806885s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_800, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 14.487556219100952s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_800, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 14.710766315460205s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_800, method_GCMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 13.31609559059143s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating GCMI object
#
#
# GCMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_assamese_female_english, budget_800, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2513, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2513 in test, shape=(2513, 39)
# creating kernels ....
# kernel creation done .... in 14.457393407821655s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_gujarati_female_english, budget_800, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1401, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1401 in test, shape=(1401, 39)
# creating kernels ....
# kernel creation done .... in 14.478710651397705s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_hindi_male_english, budget_800, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.457159280776978s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_kannada_male_english, budget_800, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1433, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1433 in test, shape=(1433, 39)
# creating kernels ....
# kernel creation done .... in 13.569331884384155s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_malayalam_male_english, budget_800, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1539, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1539 in test, shape=(1539, 39)
# creating kernels ....
# kernel creation done .... in 14.198973417282104s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_manipuri_female_english, budget_800, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (3010, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 3010 in test, shape=(3010, 39)
# creating kernels ....
# kernel creation done .... in 14.442500352859497s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_rajasthani_male_english, budget_800, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (1442, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 1442 in test, shape=(1442, 39)
# creating kernels ....
# kernel creation done .... in 14.509021043777466s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....
# ----------------------- TSS -----------------------
# accent_tamil_male_english, budget_800, method_LogDMI
# (50, 39)
# (3244, 39)
# (3491, 39)
# (3267, 39)
# (3492, 39)
# (5183, 39)
# (3169, 39)
# (6925, 39)
# (5765, 39)
# (2263, 39)
# 34536 in ground, shape=(34536, 39)
# 10 in query, shape=(10, 39)
# 2263 in test, shape=(2263, 39)
# creating kernels ....
# kernel creation done .... in 14.391089677810669s
# ground_kernel:  (34536, 34536)
# query_kernel:  (34536, 10)
# query_query_kernel:  (10, 10)
#
# creating LogDMI object
#
#
# LogDMI object created
#
#
# generating greedyList...
#
# [||||||||||||||||||||]100% [Iteration 2400 of 2400]
# .... greedyList generated ...
#
# subset computed ....

# %% [markdown]
# ### Generate the transcripts and do the grapheme to phoneme.
# -  We'll be directly using the code from error-model here

# %% [markdown]
# ### Generate the transcripts

# %%
def infer_transcripts(feature, similarity, eta, target, budget, method, accent, run):
    python_env = sys.executable
    python_file = CURR_DIR + "/models/quartznet_asr/inference.py"
    data_base_dir = CURR_DIR + f"/data/{accent}/manifests/TSS_output/all/budget_{budget}/target_{target}/{method}/eta_{eta}/{similarity}/{feature}/run_{run}/"
    wav_dir=BASE_PATH + "/data/indicTTS_audio/indicTTS/{accent}/english/wav/"
    ckpt_base_dir=CURR_DIR + "/models/pretrained_checkpoints/"
    batch_size=32
    bash_file = CURR_DIR + "/models/quartznet_asr/scripts/infer_transcriptions_on_seed_set.sh"

    
    print("------ Generating Pseudo Transcripts -------")
    print(f"accent_{accent}, budget_{budget}, method_{method}, run_{run}")
    # !export CUDA_VISIBLE_DEVICES=0,1 && bash $bash_file $python_env $python_file $data_base_dir $wav_dir $ckpt_base_dir $batch_size
    
def infer_transcripts_all():
#     ACCENTS = ["kannada_male_english"]
#     METHODS = ["FL2MI"]
#     BUDGETS = [800]
    for feature in FEATURES:
        for sim in SIM:
            for eta in ETA:
                for target in TARGET:
                    for budget in BUDGETS:
                        for method in METHODS:
                            for run in RUNS:
                                for accent in ACCENTS:
                                    infer_transcripts(
                                        feature = feature,
                                        similarity = sim,
                                        eta = eta,
                                        target = target,
                                        budget = budget,
                                        method = method,
                                        accent = accent,
                                        run = run
                                    )

# %%
infer_transcripts_all()
# Out:
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_100, method_FL2MI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:11<00:00,  5.54s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_gujarati_female_english, budget_100, method_FL2MI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 2/2 [00:14<00:00,  9.93s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_hindi_male_english, budget_100, method_FL2MI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:10<00:00,  5.21s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_kannada_male_english, budget_100, method_FL2MI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  3.90s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_malayalam_male_english, budget_100, method_FL2MI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:12<00:00,  5.89s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_manipuri_female_english, budget_100, method_FL2MI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:09<00:00,  3.03s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_rajasthani_male_english, budget_100, method_FL2MI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:12<00:00,  6.06s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_tamil_male_english, budget_100, method_FL2MI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:10<00:00,  5.07s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_100, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.38s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_gujarati_female_english, budget_100, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 2/2 [00:11<00:00,  8.25s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_hindi_male_english, budget_100, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  4.13s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_kannada_male_english, budget_100, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  3.92s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_malayalam_male_english, budget_100, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.48s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_manipuri_female_english, budget_100, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:06<00:00,  2.24s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_rajasthani_male_english, budget_100, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.53s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_tamil_male_english, budget_100, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  4.28s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_100, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.34s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_gujarati_female_english, budget_100, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 2/2 [00:11<00:00,  7.96s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_hindi_male_english, budget_100, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  4.07s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_kannada_male_english, budget_100, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  3.84s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_malayalam_male_english, budget_100, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.49s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_manipuri_female_english, budget_100, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:06<00:00,  2.19s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_rajasthani_male_english, budget_100, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.57s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_tamil_male_english, budget_100, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  4.23s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_100, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:10<00:00,  5.03s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_gujarati_female_english, budget_100, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 2/2 [00:14<00:00,  9.93s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_hindi_male_english, budget_100, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:10<00:00,  2.53s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_kannada_male_english, budget_100, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  4.16s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_malayalam_male_english, budget_100, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:11<00:00,  5.29s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_manipuri_female_english, budget_100, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:09<00:00,  3.20s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_rajasthani_male_english, budget_100, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:10<00:00,  5.12s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_tamil_male_english, budget_100, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:11<00:00,  5.36s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_100, method_GCMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.33s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_gujarati_female_english, budget_100, method_GCMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 2/2 [00:12<00:00,  8.92s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_hindi_male_english, budget_100, method_GCMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:08<00:00,  2.05s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_kannada_male_english, budget_100, method_GCMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.24s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_malayalam_male_english, budget_100, method_GCMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:10<00:00,  4.80s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_manipuri_female_english, budget_100, method_GCMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  2.42s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_rajasthani_male_english, budget_100, method_GCMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.77s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_tamil_male_english, budget_100, method_GCMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  4.27s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_100, method_GCMI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.52s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_gujarati_female_english, budget_100, method_GCMI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 2/2 [00:13<00:00,  9.08s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_hindi_male_english, budget_100, method_GCMI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:08<00:00,  2.09s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_kannada_male_english, budget_100, method_GCMI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  4.18s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_malayalam_male_english, budget_100, method_GCMI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:10<00:00,  4.85s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_manipuri_female_english, budget_100, method_GCMI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  2.39s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_rajasthani_male_english, budget_100, method_GCMI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.64s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_tamil_male_english, budget_100, method_GCMI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/GCMI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.28s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_100, method_LogDMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.42s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_gujarati_female_english, budget_100, method_LogDMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:11<00:00,  3.93s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_hindi_male_english, budget_100, method_LogDMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  2.44s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_kannada_male_english, budget_100, method_LogDMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.93s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_malayalam_male_english, budget_100, method_LogDMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.67s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_manipuri_female_english, budget_100, method_LogDMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 5/5 [00:07<00:00,  1.43s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_rajasthani_male_english, budget_100, method_LogDMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.36s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_tamil_male_english, budget_100, method_LogDMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:10<00:00,  4.70s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_100, method_LogDMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  4.23s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_gujarati_female_english, budget_100, method_LogDMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:11<00:00,  3.73s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_hindi_male_english, budget_100, method_LogDMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  2.30s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_kannada_male_english, budget_100, method_LogDMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 4/4 [00:07<00:00,  1.92s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_malayalam_male_english, budget_100, method_LogDMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.45s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_manipuri_female_english, budget_100, method_LogDMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 5/5 [00:06<00:00,  1.31s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_rajasthani_male_english, budget_100, method_LogDMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  4.13s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_tamil_male_english, budget_100, method_LogDMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:09<00:00,  4.28s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_100, method_LogDMI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_100/target_10/LogDMI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|█████████████████████████████████████████████| 3/3 [00:08<00:00,  4.15s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_gujarati_female_english, budget_100, method_LogDMI, run_3
# --------------START---------------
# ...
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|███████████████████████████████████████████| 16/16 [00:45<00:00,  1.62s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_hindi_male_english, budget_800, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|███████████████████████████████████████████| 25/25 [00:44<00:00,  1.60s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_kannada_male_english, budget_800, method_FL2MI, run_2
# 100%|███████████████████████████████████████████| 22/22 [00:48<00:00,  2.20s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_manipuri_female_english, budget_800, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|███████████████████████████████████████████| 31/31 [00:43<00:00,  1.03s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_rajasthani_male_english, budget_800, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|███████████████████████████████████████████| 21/21 [00:43<00:00,  2.05s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_tamil_male_english, budget_800, method_FL2MI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_2//quartznet_outputs
# 100%|███████████████████████████████████████████| 22/22 [00:45<00:00,  1.77s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_800, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|███████████████████████████████████████████| 22/22 [00:45<00:00,  1.73s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_gujarati_female_english, budget_800, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|███████████████████████████████████████████| 16/16 [00:45<00:00,  1.61s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_hindi_male_english, budget_800, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|███████████████████████████████████████████| 25/25 [00:44<00:00,  1.60s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_kannada_male_english, budget_800, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|███████████████████████████████████████████| 23/23 [00:45<00:00,  1.27s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_malayalam_male_english, budget_800, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|███████████████████████████████████████████| 22/22 [00:48<00:00,  2.18s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_manipuri_female_english, budget_800, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|███████████████████████████████████████████| 31/31 [00:43<00:00,  1.01it/s]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_rajasthani_male_english, budget_800, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|███████████████████████████████████████████| 21/21 [00:42<00:00,  2.02s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_tamil_male_english, budget_800, method_FL2MI, run_3
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_800/target_10/FL2MI/eta_1.0/euclidean/39/run_3//quartznet_outputs
# 100%|███████████████████████████████████████████| 22/22 [00:44<00:00,  1.76s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_800, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|███████████████████████████████████████████| 22/22 [00:49<00:00,  2.24s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_gujarati_female_english, budget_800, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/gujarati_female_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|███████████████████████████████████████████| 15/15 [00:51<00:00,  2.46s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_hindi_male_english, budget_800, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/hindi_male_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|███████████████████████████████████████████| 26/26 [00:49<00:00,  1.91s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_kannada_male_english, budget_800, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/kannada_male_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|███████████████████████████████████████████| 23/23 [00:48<00:00,  1.76s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_malayalam_male_english, budget_800, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/malayalam_male_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|███████████████████████████████████████████| 21/21 [00:44<00:00,  2.14s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_manipuri_female_english, budget_800, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/manipuri_female_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|███████████████████████████████████████████| 31/31 [00:49<00:00,  1.59s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_rajasthani_male_english, budget_800, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/rajasthani_male_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|███████████████████████████████████████████| 20/20 [00:46<00:00,  1.37s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_tamil_male_english, budget_800, method_GCMI, run_1
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/tamil_male_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_1//quartznet_outputs
# 100%|███████████████████████████████████████████| 22/22 [00:49<00:00,  2.29s/it]
# --------------DONE---------------
# ------ Generating Pseudo Transcripts -------
# accent_assamese_female_english, budget_800, method_GCMI, run_2
# --------------START---------------
# INPUTS  <--------- /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_2/
# Outputs ---------> /home/mayank/MTP/begin_again/Error-Driven-ASR-Personalization/entropy-testing/pseudo-transcript-entropy/data/assamese_female_english/manifests/TSS_output/all/budget_800/target_10/GCMI/eta_1.0/euclidean/39/run_2//quartznet_outputs
#  18%|████████                                    | 4/22 [00:10<01:01,  3.44s/it]

# %% [markdown]
# #### Get the phoneme versions

# %% [markdown]
# #### Do the TF-IDF vectors

# %% [markdown]
# #### Make selections using some submodlib utility
