# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import re, os, csv, pathlib, ast
import pandas as pd
from statistics import mean, variance

def replace_with_short_forms(s):
    s=s.replace('english','')
    s=s.replace('_female_','[F]')
    s=s.replace('_male_','[M]')
    return s

def shortened_speaker(s):
    accent,gender,_=s.split('_')
    return accent[0].upper()+accent[1:]+'['+gender[0].upper()+']'

def last_name(pth):
    return pathlib.PurePath(pth).name

def get_dirs(pth):
    return [last_name(f.name) for f in os.scandir(pth) if f.is_dir()]

def get_each_run(lne):
    return list(map(float, re.findall(': (.+?) -> ', lne)[0].split(' ')))

def get_selection_counts(s):
    return list(map(replace_with_short_forms, re.findall('Counter\\((.+?)\\)', s)))

def get_test(stats_file_path):
    return stats_file_path[:-9]+"run_1/output/test_infer_log.txt"

def get_test_file_from_stats_path(run_number, stats_file_opened):
    return stats_file_opened.name[:-9]+"run_{}/output/test_infer_log.txt".format(run_number)

def WER_test_file(test_file):
    txt_file = open(test_file, 'r')
    lines = txt_file.readlines()
    matched = ""
    for line in lines:
        if "==========>>>>>>Evaluation Greedy WER: " in line:
            txt_file.close()
            return float(line.rstrip().split(": ")[1])
    txt_file.close()
    return ""

def get_eta(func, eta):
    return "-n:"+str(float(eta[4:]))

# %%
# budget = 100
# target = 50
budget = 100
target = 10
features = '39'
# features = 'TRILL'
csv_name = "report_{}_{}_{}.csv".format(budget, target, features)

# %%
# sample_path = 'Error-Driven-ASR-Personalization/CMU_expts/speaker/hindi/manifests/TSS_output/all/budget_100/target_50/FL1MI/eta_1.0/euclidean/39/stats.txt'
# CMU_expts/speaker_without/ABA/manifests/TSS_output/all/budget_100/target_50/FL1MI/eta_1.0/euclidean/39/run_1/
# budget = 200
# target = 80

cols = ['speaker', 'ground', 'function', 'similarity', 'duration', 'samples', 
        'WER-r1', 'WER-r2', 'WER-r3', 'WER-mean', 'WER-stdev', 'speakers_run1', 'speakers_run2', 'speakers_run3']
df = pd.DataFrame(columns = cols)

speakers = [f.name for f in os.scandir('./') if f.is_dir() and 'english' in f.name]

# not random
for speaker in speakers:
    if not(pathlib.Path('./{}/manifests/TSS_output/'.format(speaker)).is_dir()):
        print("no results for speaker {}".format(speaker))
        continue
    if 'within' not in get_dirs('./{}/manifests/TSS_output/'.format(speaker)):
        print("no within results for {}".format(speaker))
        continue
    if not(os.path.isdir('./{}/manifests/TSS_output/within/budget_{}/target_{}/'.format(speaker, budget, target))):
        continue
    for function in get_dirs('./{}/manifests/TSS_output/within/budget_{}/target_{}/'.format(speaker, budget, target)):
        if 'deprecated' in function:
            continue
        stats_file_path='./{}/manifests/TSS_output/within/budget_{}/target_{}/{}/stats.txt'.format(speaker, budget, target, function)
        if not(os.path.isfile(stats_file_path)):
            # print(cnt,"99999999999")
            print(stats_file_path+" not found")
            continue
        if not(os.path.isfile(get_test(stats_file_path))):
            print(get_test(stats_file_path)+" not found")
            continue
        stats_file = open(stats_file_path, 'r')
        lines = stats_file.readlines()
        df_selections = get_selection_counts(lines[5])
        total_selections, total_durations, speakered_selections, speakered_durations = map(get_each_run, lines[:4])
        sample_frac = mean([x[0]/x[1] for x in zip(speakered_selections, total_selections)])
        sample_total = mean(total_selections)
        duration_frac = mean([x[0]/x[1] for x in zip(speakered_durations, total_durations)])
        duration_total = mean(total_durations)
        df_duration = "{:.2f}/{:.2f}".format(duration_total*duration_frac, duration_total)
        df_samples = "{:.2f}/{:.2f}".format(sample_total*sample_frac, sample_total)
        try:
            wers = [WER_test_file(get_test_file_from_stats_path(i, stats_file)) for i in range(1,4)]
            wers = [x for x in wers if type(x)==float or type(x)==int]
            df_wer_mean = round(mean(wers), 2)
            df_wer_stdev = round(variance(wers), 3)**0.5
        except:
            print("no WER's in file", get_test_file_from_stats_path(1, stats_file))
            wers = [0,0,0]
            df_wer_mean = 0
            df_wer_stdev = 999
        df = df.append(dict(zip(cols, [shortened_speaker(speaker), "within", function, "NA", df_duration, df_samples]+
                                       wers+[df_wer_mean, round(df_wer_stdev, 3)] + df_selections)), 
                       ignore_index=True)
        stats_file.close()

df = df.sort_values(by=['speaker', 'similarity', 'ground', 'function'], ascending=True, ignore_index=True)
display(df)
# Out:
#          speaker  ground function similarity       duration        samples  \
# 0    Assamese[F]  within   random         NA  489.78/489.78    97.00/97.00
# 1    Gujarati[F]  within   random         NA  485.51/485.51    65.00/65.00
# 2       Hindi[M]  within   random         NA  490.24/490.24  102.33/102.33
# 3     Kannada[M]  within   random         NA  487.74/487.74    91.33/91.33
# 4   Malayalam[M]  within   random         NA  490.80/490.80    91.00/91.00
# 5    Manipuri[F]  within   random         NA  490.30/490.30  132.33/132.33
# 6  Rajasthani[M]  within   random         NA  487.15/487.15    91.67/91.67
# 7       Tamil[M]  within   random         NA  488.66/488.66    96.33/96.33
#
#    WER-r1  WER-r2  WER-r3  WER-mean  WER-stdev          speakers_run1  \
# 0   20.16   19.64   19.45     19.75      0.367    {'assamese[F]': 99}
# 1   10.26    9.93   10.31     10.17      0.207    {'gujarati[F]': 61}
# 2    8.39    9.20    9.09      8.89      0.439       {'hindi[M]': 99}
# 3   14.58   13.88   14.13     14.20      0.355     {'kannada[M]': 90}
# 4   15.72   16.12   15.45     15.76      0.338   {'malayalam[M]': 92}
# 5   42.09   42.46   41.90     42.15      0.285   {'manipuri[F]': 129}
# 6   15.58   16.06   15.76     15.80      0.243  {'rajasthani[M]': 93}
# 7   11.76   11.93   12.07     11.92      0.155       {'tamil[M]': 91}
#
#            speakers_run2          speakers_run3
# 0    {'assamese[F]': 98}    {'assamese[F]': 94}
# 1    {'gujarati[F]': 66}    {'gujarati[F]': 68}
# 2      {'hindi[M]': 104}      {'hindi[M]': 104}
# 3     {'kannada[M]': 94}     {'kannada[M]': 90}
# 4   {'malayalam[M]': 91}   {'malayalam[M]': 90}
# 5   {'manipuri[F]': 133}   {'manipuri[F]': 135}
# 6  {'rajasthani[M]': 92}  {'rajasthani[M]': 90}
# 7       {'tamil[M]': 99}       {'tamil[M]': 99}

# %%
# total selection : 100 100 100 -> 100.00
# total selection duration: 357.0149433106577 357.0149433106577 357.0149433106577 -> 357.01
# speakered selection: 76 76 76 -> 76.00
# speakered duration: 254.74947845804974 254.74947845804974 254.74947845804974 -> 254.75

# all selections: [Counter({'hindi': 76, 'korean': 8, 'spanish': 7, 'arabic': 3, 'chinese': 3, 'vietnamese': 3}), Counter({'hindi': 76, 'korean': 8, 'spanish': 7, 'arabic': 3, 'chinese': 3, 'vietnamese': 3}), Counter({'hindi': 76, 'korean': 8, 'spanish': 7, 'arabic': 3, 'chinese': 3, 'vietnamese': 3})]

#Evaluation Greedy WER: 16.19

df2 = pd.read_csv(csv_name)
df2=df2.append(df)
df2 = df2.sort_values(by=['speaker', 'ground', 'similarity', 'function'], ascending=True, ignore_index=True)
display(df2)
# Out:
#           speaker  ground      function similarity       duration  \
# 0     Assamese[F]     all   FL1MI-n:1.0  euclidean  460.04/491.51
# 1     Assamese[F]     all   FL2MI-n:1.0  euclidean  487.83/487.83
# 2     Assamese[F]     all    GCMI-n:1.0  euclidean  490.36/490.36
# 3     Assamese[F]     all  LogDMI-n:1.0  euclidean  477.89/484.48
# 4     Assamese[F]     all        random        NaN   81.27/490.10
# 5     Assamese[F]  within        random         NA  489.78/489.78
# 6     Gujarati[F]     all   FL1MI-n:1.0  euclidean  426.61/491.36
# 7     Gujarati[F]     all   FL2MI-n:1.0  euclidean  490.55/490.55
# 8     Gujarati[F]     all    GCMI-n:1.0  euclidean  488.14/488.14
# 9     Gujarati[F]     all  LogDMI-n:1.0  euclidean  487.59/487.59
# 10    Gujarati[F]     all        random        NaN   59.88/490.10
# 11    Gujarati[F]  within        random         NA  485.51/485.51
# 12    Gujarati[F]  within        random        NaN  485.51/485.51
# 13       Hindi[M]     all   FL1MI-n:1.0  euclidean  326.56/491.28
# 14       Hindi[M]     all   FL2MI-n:1.0  euclidean  488.52/488.52
# 15       Hindi[M]     all    GCMI-n:1.0  euclidean  488.65/488.65
# 16       Hindi[M]     all  LogDMI-n:1.0  euclidean  460.19/489.16
# 17       Hindi[M]     all        random        NaN   51.68/490.10
# 18       Hindi[M]  within        random         NA  490.24/490.24
# 19       Hindi[M]  within        random        NaN  490.24/490.24
# 20     Kannada[M]     all   FL1MI-n:1.0  euclidean  349.77/491.76
# 21     Kannada[M]     all   FL2MI-n:1.0  euclidean  491.35/491.35
# 22     Kannada[M]     all    GCMI-n:1.0  euclidean  490.53/490.53
# 23     Kannada[M]     all  LogDMI-n:1.0  euclidean  475.68/489.07
# 24     Kannada[M]     all        random        NaN   39.57/490.10
# 25     Kannada[M]  within        random         NA  487.74/487.74
# 26     Kannada[M]  within        random        NaN  487.74/487.74
# 27   Malayalam[M]     all   FL1MI-n:1.0  euclidean  462.47/491.52
# 28   Malayalam[M]     all   FL2MI-n:1.0  euclidean  491.66/491.66
# 29   Malayalam[M]     all    GCMI-n:1.0  euclidean  487.43/487.43
# 30   Malayalam[M]     all  LogDMI-n:1.0  euclidean  467.48/487.72
# 31   Malayalam[M]     all        random        NaN   38.75/490.10
# 32   Malayalam[M]  within        random         NA  490.80/490.80
# 33   Malayalam[M]  within        random        NaN  490.80/490.80
# 34    Manipuri[F]     all   FL1MI-n:1.0  euclidean  332.41/487.76
# 35    Manipuri[F]     all   FL2MI-n:1.0  euclidean  489.19/489.19
# 36    Manipuri[F]     all    GCMI-n:1.0  euclidean  489.43/489.43
# 37    Manipuri[F]     all  LogDMI-n:1.0  euclidean  491.14/491.14
# 38    Manipuri[F]     all        random        NaN   64.80/490.10
# 39    Manipuri[F]  within        random         NA  490.30/490.30
# 40    Manipuri[F]  within        random        NaN  490.30/490.30
# 41  Rajasthani[M]     all   FL1MI-n:1.0  euclidean  477.57/490.38
# 42  Rajasthani[M]     all   FL2MI-n:1.0  euclidean  485.96/485.96
# 43  Rajasthani[M]     all    GCMI-n:1.0  euclidean  489.56/489.56
# 44  Rajasthani[M]     all  LogDMI-n:1.0  euclidean  491.04/491.04
# 45  Rajasthani[M]     all        random        NaN   53.20/490.10
# 46  Rajasthani[M]  within        random         NA  487.15/487.15
# 47       Tamil[M]     all   FL1MI-n:1.0  euclidean  398.98/490.31
# 48       Tamil[M]     all   FL2MI-n:1.0  euclidean  485.00/485.00
# 49       Tamil[M]     all    GCMI-n:1.0  euclidean  486.03/486.03
# 50       Tamil[M]     all  LogDMI-n:1.0  euclidean  486.36/489.33
# 51       Tamil[M]     all        random        NaN  100.95/490.10
# 52       Tamil[M]  within        random         NA  488.66/488.66
#
#           samples  WER-r1  WER-r2  WER-r3  WER-mean  WER-var  \
# 0     86.00/93.00   20.19   19.99   20.18     20.12    0.013
# 1     80.00/80.00   20.28   20.23   20.28     20.26    0.001
# 2     81.00/81.00   20.50   20.38   20.31     20.40    0.009
# 3     90.00/92.00   19.95   19.86   19.87     19.89    0.002
# 4     17.52/99.67   22.56   23.55   23.53     23.21    0.320
# 5     97.00/97.00   20.16   19.64   19.45     19.75      NaN
# 6     51.00/65.00   10.22   10.15   10.16     10.18    0.001
# 7     61.00/61.00   10.00    9.93   10.00      9.98    0.002
# 8     55.00/55.00   10.25   10.23   10.73     10.40    0.080
# 9     65.00/65.00    9.83    9.85    9.82      9.83    0.000
# 10     7.83/99.67   10.74   11.77   11.11     11.21    0.272
# 11    65.00/65.00   10.26    9.93   10.31     10.17      NaN
# 12    65.00/65.00   10.26    9.93   10.31     10.17    0.043
# 13   69.00/100.00    9.42    9.30    9.46      9.39    0.007
# 14    94.00/94.00   10.03    9.33    9.40      9.59    0.149
# 15  103.00/103.00    9.56    9.55    9.75      9.62    0.013
# 16  107.00/113.00    9.09    9.10    9.07      9.09    0.000
# 17    11.07/99.67    9.48   10.01   10.09      9.86    0.110
# 18  102.33/102.33    8.39    9.20    9.09      8.89      NaN
# 19  102.33/102.33    8.39    9.20    9.09      8.89    0.193
# 20    62.00/90.00   15.35   15.22   15.23     15.27    0.005
# 21    92.00/92.00   14.28   14.11   13.83     14.07    0.052
# 22    86.00/86.00   13.93   13.90   13.86     13.90    0.001
# 23  103.00/107.00   14.80   14.79   14.71     14.77    0.002
# 24     8.25/99.67   15.55   15.94   15.89     15.79    0.045
# 25    91.33/91.33   14.58   13.88   14.13     14.20      NaN
# 26    91.33/91.33   14.58   13.88   14.13     14.20    0.126
# 27    81.00/87.00   15.49   15.60   15.53     15.54    0.003
# 28    83.00/83.00   15.21   15.63   15.23     15.36    0.056
# 29    78.00/78.00   15.63   15.73   15.82     15.73    0.009
# 30    81.00/85.00   15.79   15.43   15.73     15.65    0.037
# 31     8.24/99.67   18.54   18.09   17.89     18.17    0.111
# 32    91.00/91.00   15.72   16.12   15.45     15.76      NaN
# 33    91.00/91.00   15.72   16.12   15.45     15.76    0.114
# 34   84.00/113.00   41.93   41.74   41.64     41.77    0.022
# 35  118.00/118.00   41.92   41.74   41.69     41.78    0.015
# 36  110.00/110.00   42.82   42.82   42.44     42.69    0.048
# 37  133.00/133.00   42.38   42.39   42.41     42.39    0.000
# 38    17.61/99.67   46.48   47.10   47.35     46.98    0.201
# 39  132.33/132.33   42.09   42.46   41.90     42.15      NaN
# 40  132.33/132.33   42.09   42.46   41.90     42.15    0.081
# 41    85.00/87.00   15.44   15.52   15.53     15.50    0.002
# 42    75.00/75.00   15.72   15.63   15.77     15.71    0.005
# 43    76.00/76.00   15.22   15.46   15.26     15.31    0.017
# 44    90.00/90.00   15.20   15.45   15.04     15.23    0.043
# 45     9.76/99.67   16.40   16.83   17.39     16.87    0.246
# 46    91.67/91.67   15.58   16.06   15.76     15.80      NaN
# 47    75.00/96.00   11.86   11.88   11.89     11.88    0.000
# 48    82.00/82.00   11.80   11.79   11.77     11.79    0.000
# 49    86.00/86.00   11.67   11.66   11.66     11.66    0.000
# 50    89.00/90.00   12.26   12.26   12.26     12.26    0.000
# 51    19.38/99.67   11.85   12.07   11.71     11.88    0.033
# 52    96.33/96.33   11.76   11.93   12.07     11.92      NaN
#
#                                         speakers_run1  \
# 0   {'assamese[F]': 86, 'manipuri[F]': 4, 'gujarat...
# 1                                 {'assamese[F]': 80}
# 2                                 {'assamese[F]': 81}
# 3               {'assamese[F]': 90, 'manipuri[F]': 2}
# 4   {'assamese[F]': 19, 'tamil[M]': 19, 'manipuri[...
# 5                                 {'assamese[F]': 99}
# 6   {'gujarati[F]': 51, 'assamese[F]': 12, 'kannad...
# 7                                 {'gujarati[F]': 61}
# 8                                 {'gujarati[F]': 55}
# 9                                 {'gujarati[F]': 65}
# 10  {'assamese[F]': 19, 'tamil[M]': 19, 'manipuri[...
# 11                                {'gujarati[F]': 61}
# 12                                {'gujarati[F]': 61}
# 13  {'hindi[M]': 69, 'assamese[F]': 25, 'malayalam...
# 14                                   {'hindi[M]': 94}
# 15                                  {'hindi[M]': 103}
# 16  {'hindi[M]': 107, 'malayalam[M]': 4, 'kannada[...
# 17  {'assamese[F]': 19, 'tamil[M]': 19, 'manipuri[...
# 18                                   {'hindi[M]': 99}
# 19                                   {'hindi[M]': 99}
# 20  {'kannada[M]': 62, 'assamese[F]': 18, 'malayal...
# 21                                 {'kannada[M]': 92}
# 22                                 {'kannada[M]': 86}
# 23             {'kannada[M]': 103, 'malayalam[M]': 4}
# 24  {'assamese[F]': 19, 'tamil[M]': 19, 'manipuri[...
# 25                                 {'kannada[M]': 90}
# 26                                 {'kannada[M]': 90}
# 27  {'malayalam[M]': 81, 'kannada[M]': 3, 'hindi[M...
# 28                               {'malayalam[M]': 83}
# 29                               {'malayalam[M]': 78}
# 30              {'malayalam[M]': 81, 'kannada[M]': 4}
# 31  {'assamese[F]': 19, 'tamil[M]': 19, 'manipuri[...
# 32                               {'malayalam[M]': 92}
# 33                               {'malayalam[M]': 92}
# 34  {'manipuri[F]': 84, 'assamese[F]': 28, 'gujara...
# 35                               {'manipuri[F]': 118}
# 36                               {'manipuri[F]': 110}
# 37                               {'manipuri[F]': 133}
# 38  {'assamese[F]': 19, 'tamil[M]': 19, 'manipuri[...
# 39                               {'manipuri[F]': 129}
# 40                               {'manipuri[F]': 129}
# 41  {'rajasthani[M]': 85, 'malayalam[M]': 1, 'hind...
# 42                              {'rajasthani[M]': 75}
# 43                              {'rajasthani[M]': 76}
# 44                              {'rajasthani[M]': 90}
# 45  {'assamese[F]': 19, 'tamil[M]': 19, 'manipuri[...
# 46                              {'rajasthani[M]': 93}
# 47  {'tamil[M]': 75, 'assamese[F]': 14, 'kannada[M...
# 48                                   {'tamil[M]': 82}
# 49                                   {'tamil[M]': 86}
# 50                {'tamil[M]': 89, 'malayalam[M]': 1}
# 51  {'assamese[F]': 19, 'tamil[M]': 19, 'manipuri[...
# 52                                   {'tamil[M]': 91}
#
#                                         speakers_run2  \
# 0   {'assamese[F]': 86, 'manipuri[F]': 4, 'gujarat...
# 1                                 {'assamese[F]': 80}
# 2                                 {'assamese[F]': 81}
# 3               {'assamese[F]': 90, 'manipuri[F]': 2}
# 4   {'manipuri[F]': 22, 'assamese[F]': 17, 'tamil[...
# 5                                 {'assamese[F]': 98}
# 6   {'gujarati[F]': 51, 'assamese[F]': 12, 'kannad...
# 7                                 {'gujarati[F]': 61}
# 8                                 {'gujarati[F]': 55}
# 9                                 {'gujarati[F]': 65}
# 10  {'manipuri[F]': 22, 'assamese[F]': 17, 'tamil[...
# 11                                {'gujarati[F]': 66}
# 12                                {'gujarati[F]': 66}
# 13  {'hindi[M]': 69, 'assamese[F]': 25, 'malayalam...
# 14                                   {'hindi[M]': 94}
# 15                                  {'hindi[M]': 103}
# 16  {'hindi[M]': 107, 'malayalam[M]': 4, 'kannada[...
# 17  {'manipuri[F]': 22, 'assamese[F]': 17, 'tamil[...
# 18                                  {'hindi[M]': 104}
# 19                                  {'hindi[M]': 104}
# 20  {'kannada[M]': 62, 'assamese[F]': 18, 'malayal...
# 21                                 {'kannada[M]': 92}
# 22                                 {'kannada[M]': 86}
# 23             {'kannada[M]': 103, 'malayalam[M]': 4}
# 24  {'manipuri[F]': 22, 'assamese[F]': 17, 'tamil[...
# 25                                 {'kannada[M]': 94}
# 26                                 {'kannada[M]': 94}
# 27  {'malayalam[M]': 81, 'kannada[M]': 3, 'hindi[M...
# 28                               {'malayalam[M]': 83}
# 29                               {'malayalam[M]': 78}
# 30              {'malayalam[M]': 81, 'kannada[M]': 4}
# 31  {'manipuri[F]': 22, 'assamese[F]': 17, 'tamil[...
# 32                               {'malayalam[M]': 91}
# 33                               {'malayalam[M]': 91}
# 34  {'manipuri[F]': 84, 'assamese[F]': 28, 'gujara...
# 35                               {'manipuri[F]': 118}
# 36                               {'manipuri[F]': 110}
# 37                               {'manipuri[F]': 133}
# 38  {'manipuri[F]': 22, 'assamese[F]': 17, 'tamil[...
# 39                               {'manipuri[F]': 133}
# 40                               {'manipuri[F]': 133}
# 41  {'rajasthani[M]': 85, 'malayalam[M]': 1, 'hind...
# 42                              {'rajasthani[M]': 75}
# 43                              {'rajasthani[M]': 76}
# 44                              {'rajasthani[M]': 90}
# 45  {'manipuri[F]': 22, 'assamese[F]': 17, 'tamil[...
# 46                              {'rajasthani[M]': 92}
# 47  {'tamil[M]': 75, 'assamese[F]': 14, 'kannada[M...
# 48                                   {'tamil[M]': 82}
# 49                                   {'tamil[M]': 86}
# 50                {'tamil[M]': 89, 'malayalam[M]': 1}
# 51  {'manipuri[F]': 22, 'assamese[F]': 17, 'tamil[...
# 52                                   {'tamil[M]': 99}
#
#                                         speakers_run3  WER-stdev
# 0   {'assamese[F]': 86, 'manipuri[F]': 4, 'gujarat...        NaN
# 1                                 {'assamese[F]': 80}        NaN
# 2                                 {'assamese[F]': 81}        NaN
# 3               {'assamese[F]': 90, 'manipuri[F]': 2}        NaN
# 4   {'tamil[M]': 22, 'manipuri[F]': 17, 'assamese[...        NaN
# 5                                 {'assamese[F]': 94}      0.367
# 6   {'gujarati[F]': 51, 'assamese[F]': 12, 'kannad...        NaN
# 7                                 {'gujarati[F]': 61}        NaN
# 8                                 {'gujarati[F]': 55}        NaN
# 9                                 {'gujarati[F]': 65}        NaN
# 10  {'tamil[M]': 22, 'manipuri[F]': 17, 'assamese[...        NaN
# 11                                {'gujarati[F]': 68}      0.207
# 12                                {'gujarati[F]': 68}        NaN
# 13  {'hindi[M]': 69, 'assamese[F]': 25, 'malayalam...        NaN
# 14                                   {'hindi[M]': 94}        NaN
# 15                                  {'hindi[M]': 103}        NaN
# 16  {'hindi[M]': 107, 'malayalam[M]': 4, 'kannada[...        NaN
# 17  {'tamil[M]': 22, 'manipuri[F]': 17, 'assamese[...        NaN
# 18                                  {'hindi[M]': 104}      0.439
# 19                                  {'hindi[M]': 104}        NaN
# 20  {'kannada[M]': 62, 'assamese[F]': 18, 'malayal...        NaN
# 21                                 {'kannada[M]': 92}        NaN
# 22                                 {'kannada[M]': 86}        NaN
# 23             {'kannada[M]': 103, 'malayalam[M]': 4}        NaN
# 24  {'tamil[M]': 22, 'manipuri[F]': 17, 'assamese[...        NaN
# 25                                 {'kannada[M]': 90}      0.355
# 26                                 {'kannada[M]': 90}        NaN
# 27  {'malayalam[M]': 81, 'kannada[M]': 3, 'hindi[M...        NaN
# 28                               {'malayalam[M]': 83}        NaN
# 29                               {'malayalam[M]': 78}        NaN
# 30              {'malayalam[M]': 81, 'kannada[M]': 4}        NaN
# 31  {'tamil[M]': 22, 'manipuri[F]': 17, 'assamese[...        NaN
# 32                               {'malayalam[M]': 90}      0.338
# 33                               {'malayalam[M]': 90}        NaN
# 34  {'manipuri[F]': 84, 'assamese[F]': 28, 'gujara...        NaN
# 35                               {'manipuri[F]': 118}        NaN
# 36                               {'manipuri[F]': 110}        NaN
# 37                               {'manipuri[F]': 133}        NaN
# 38  {'tamil[M]': 22, 'manipuri[F]': 17, 'assamese[...        NaN
# 39                               {'manipuri[F]': 135}      0.285
# 40                               {'manipuri[F]': 135}        NaN
# 41  {'rajasthani[M]': 85, 'malayalam[M]': 1, 'hind...        NaN
# 42                              {'rajasthani[M]': 75}        NaN
# 43                              {'rajasthani[M]': 76}        NaN
# 44                              {'rajasthani[M]': 90}        NaN
# 45  {'tamil[M]': 22, 'manipuri[F]': 17, 'assamese[...        NaN
# 46                              {'rajasthani[M]': 90}      0.243
# 47  {'tamil[M]': 75, 'assamese[F]': 14, 'kannada[M...        NaN
# 48                                   {'tamil[M]': 82}        NaN
# 49                                   {'tamil[M]': 86}        NaN
# 50                {'tamil[M]': 89, 'malayalam[M]': 1}        NaN
# 51  {'tamil[M]': 22, 'manipuri[F]': 17, 'assamese[...        NaN
# 52                                   {'tamil[M]': 99}      0.155

# %%
df2.to_csv(csv_name, index=False)
