# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import re, os, csv, pathlib, ast, os.path, itertools, json, time
import pandas as pd
from statistics import mean, variance
from collections import Counter
from os import path
from datetime import datetime, timedelta

pd.set_option('display.max_rows', None)

def accent_from_path(json_path):
    pieces = json_path.split('/')
    piece = [piece for piece in pieces if 'english' in piece]
    piece = piece[0]
    return replace_with_short_forms(piece)

def WER_test_file(test_file):
    try:
        txt_file = open(test_file, 'r')
        lines = txt_file.readlines()
        matched = ""
        for line in lines:
            if "==========>>>>>>Evaluation Greedy WER: " in line:
                txt_file.close()
                return float(line.rstrip().split(": ")[1])
        txt_file.close()
    except:
        print("WER not found in {}".format(test_file))

        
        
def CER_test_file(test_file):
    try:
        txt_file = open(test_file, 'r')
        lines = txt_file.readlines()
        matched = ""
        for line in lines:
            if "==========>>>>>>Evaluation Greedy CER: " in line:
                txt_file.close()
                return float(line.rstrip().split(": ")[1])
        txt_file.close()
    except:
        print("CER not found in {}".format(test_file))
        

def accent_distribution(json_path):
    file = open(json_path, 'r')
    paths = [accent_from_path(json.loads(sample)['audio_filepath'])[:3] for sample in file.readlines()]
    counts = Counter(paths)
    return dict(counts.most_common())

def time_fraction(json_parent, speaker):
    total_duration, domain_duration = 0, 0
    for i in range(1,4):
        json_path = "{}/run_{}/train.json".format(json_parent, i)
        file = open(json_path, 'r')
        samples = [sample for sample in file.readlines()]
        total_duration += sum([json.loads(sample)['duration'] for sample in samples])
        domain_duration += sum([json.loads(sample)['duration'] for sample in samples if speaker in json.loads(sample)['audio_filepath'].split('/')])
#         print(speaker, json.loads(samples[0])['audio_filepath'])
    total_duration/=3
    domain_duration/=3
    return "{:.1f}/{:.1f}".format(domain_duration, total_duration)

def sample_fraction(json_parent, speaker):
    total, domain_counts = 0, 0
    for i in range(1,4):
        json_path = "{}/run_{}/train.json".format(json_parent, i)
        file = open(json_path, 'r')
        total += len([json.loads(sample) for sample in file.readlines()])
        domain_counts += len([json.loads(sample) for sample in file.readlines() if speaker in json.loads(
            sample)['audio_filepath'].split('/')])
    total/=3
    domain_counts/=3
    return "{:.1f}/{:.1f}".format(domain_counts, total)

def replace_with_short_forms(s):
    s=s.replace('english','')
    s=s.replace('_female_','[F]')
    s=s.replace('_male_','[M]')
    return s


def last_name(pth):
    return pathlib.PurePath(pth).name

def get_dirs(pth):
    return [last_name(f.name) for f in os.scandir(pth) if f.is_dir()]

def get_each_run(lne):
    return list(map(float, re.findall(': (.+?) -> ', lne)[0].split(' ')))

def get_selection_counts(s):
    return list(map(replace_with_short_forms, re.findall('Counter\\((.+?)\\)', s)))


def get_test(stats_file_path):
    return stats_file_path[:-9]+"run_1/output/test_out.txt"

def get_eta(func, eta):
    return "-n:"+str(float(eta[4:]))

# %%
pth='assamese_female_english/all/budget_2000/target_20/FL2MI/39/train.json'
accent_from_path(pth)
# Out:
# 'assamese[F]'

# %%
# sample_path = 'Error-Driven-ASR-Personalization/CMU_expts/speaker/hindi/manifests/TSS_output/all/budget_100/target_50/FL1MI/eta_1.0/euclidean/39/stats.txt'
# assamese_female_english/all/budget_2000/target_20/FL2MI/39/budget_200/error_model/run_1
# budget = 100


ft, b1, b2, t = '39', '3500', 150, 20
csv_name = "unfmted_rpt_{}_{}_{}_{}.csv".format(b1, t, ft, b2)

cols = ['speaker', 'ground', 'stage1', 'ft', 'stage2', 'duration',  
        'WER-r1', 'WER-r2', 'WER-r3', 'WER-mean', 'WER-stdev', 'distn_1', 'distn_2', 'distn_3']
df = pd.DataFrame(columns = cols)

# speakers = ['assamese_female_english', 'gujarati_female_english', 'manipuri_female_english', 'hindi_male_english',
#             'rajasthani_male_english', 'tamil_male_english', 'kannada_male_english', 'malayalam_male_english']
speakers = ["assamese_female_english", "kannada_male_english"]
cnt = 0

speaker_pre_added={}
for speaker in speakers: 
    speaker_pre_added[speaker] = False

print(speakers)
for speaker in speakers:
    
    #starting with random
    pick_from = 'all'
    curr_dir = '{}/all/budget_{}/random'.format(speaker, b2)
    random_present = True
    for i in range(1,4):
        if not(pathlib.Path('{}/run_{}'.format(curr_dir, i)).is_dir()): 
            print("run_{} missing {}/run_{}".format(i, curr_dir, i))
            random_present = False
    if random_present:
        selection_stats = [accent_distribution('{}/run_{}/train.json'.format(curr_dir, i)) for i in range(1,4)]
        
        df_duration = time_fraction(curr_dir, speaker)
        df_samples = sample_fraction(curr_dir, speaker)
        try:
            wers = [WER_test_file('{}/run_{}/test_infer_log.txt'.format(curr_dir, i)) for i in range(1,4)]
            df_wer_mean = round(mean(wers), 2)
            df_wer_stdev = round(variance(wers)**0.5, 3)
        except:
            print("WER extraction failed ", curr_dir)
            wers = [0,0,0]
            df_wer_mean = 0
            df_wer_stdev = 999
#         if fun=='random': fun='rand'
        df = df.append(dict(zip(cols, [replace_with_short_forms(speaker), pick_from, 'rand {}'.format(b2), '-', '-', df_duration]+wers
                                +[df_wer_mean, df_wer_stdev] + selection_stats)), ignore_index=True)    
    #starting with TSS
#     for fun, method in itertools.product(['FL2MI', 'GCMI', 'LogDMI'], ['random', 'top', 'error_model']):
#     for fun, method in itertools.product(['FL2MI'], ['random', 'top', 'error_model', 'div_tf_idf', 'w2v2_avg', 'true_wer', 'div_tf_idf_3gram_cosine', 'div_tf_idf_4gram_euclidean']):
    for fun, method in itertools.product(['FL2MI'], ['uniform', 'div_tf_idf_2gram_euclidean/LogDet', 'div_tf_idf_2gram_euclidean', 'div_tf_idf_3gram_euclidean', 'random']):
        if not(pathlib.Path('{}/{}/budget_{}/target_{}/{}/{}/budget_{}/{}'.format(speaker, pick_from, b1, t, 
                                                                               fun, ft, b2, method)).is_dir()):
            print('expt_dr {}/{}/budget_{}/target_{}/{}/{}/budget_{}/{}\n is not found'.format(speaker, pick_from, b1, t, fun, ft, b2, method))
            continue
        curr_dir = '{}/{}/budget_{}/target_{}/{}/{}/budget_{}/{}'.format(speaker, pick_from, b1, t, 
                                                                               fun, ft, b2, method)
        for i in range(1,4):
            if not(pathlib.Path('{}/run_{}'.format(curr_dir, i)).is_dir()): print("l28 run_{} missing {}/run_{}".format(i, curr_dir, i))
        selection_stats = [accent_distribution('{}/run_{}/train.json'.format(curr_dir, i)) for i in range(1,4)]
        
        df_duration = time_fraction(curr_dir, speaker)
        df_samples = sample_fraction(curr_dir, speaker)
        try:
            wers = [WER_test_file('{}/run_{}/test_infer_log.txt'.format(curr_dir, i)) for i in range(1,4)]
            df_wer_mean = round(mean(wers), 2)
            df_wer_stdev = round(variance(wers)**0.5, 3)
        except:
            continue
            print("WER extraction failed ", curr_dir)
            wers = [0,0,0]
            df_wer_mean = 0
            df_wer_stdev = 999
#         print(fun)
        if method=='error_model': method='error'
        if method=='true_wer': method='wer_skyline'
#         if method=='w2v2_avg': method='w2v2'
        if method=='random': method='rand'
        df = df.append(dict(zip(cols, [replace_with_short_forms(speaker), pick_from, "{} {}".format(fun,b1), 
                                       ft, "{} {}".format(method,b2), df_duration]+wers
                                +[df_wer_mean, df_wer_stdev] + selection_stats)), ignore_index=True)
        #pretrain vals
        if not(speaker_pre_added[speaker]):
            speaker_pre_added[speaker]=True
            df_wer_mean = WER_test_file('{}/TSS_output/pre_test_infer_log.txt'.format(speaker))
            df_wer_stdev = 0
            df = df.append(dict(zip(cols, [replace_with_short_forms(speaker), 'all', '~pretrain', '-', '-', '-', '-',  '-',  '-']
                                +[df_wer_mean, df_wer_stdev] + ['-',  '-',  '-'])), ignore_index=True)
    

# cols = ['speaker', 'ground', 'stage1', 'ft', 'stage2', 'duration', 'samples', 
#         'WER-r1', 'WER-r2', 'WER-r3', 'WER-mean', 'WER-stdev', 'distn_1', 'distn_2', 'distn_3']
custom_dict = {f'wer_skyline {b2}': 0, f'error {b2}': 1, f'top {b2}': 2, f'div_tf_idf {b2}': 3,  f'w2v2_avg {b2}': 4, 
               f'rand {b2}': 5, } 
df = df.sort_values(by=['stage2'], key=lambda x: x.map(custom_dict))
df = df.sort_values(by=['speaker', 'stage1', 'ft', 'ground'], ascending=[True, True, True, True], ignore_index=True)
# df = df.sort_values(by=['speaker', 'stage1', 'ft', 'ground', 'stage2'], ascending=[True, True, True, True, True], ignore_index=True)

display(df)
# Out:
# ['assamese_female_english', 'kannada_male_english']
# run_1 missing assamese_female_english/all/budget_150/random/run_1
# run_2 missing assamese_female_english/all/budget_150/random/run_2
# run_3 missing assamese_female_english/all/budget_150/random/run_3
# expt_dr assamese_female_english/all/budget_3500/target_20/FL2MI/39/budget_150/div_tf_idf_2gram_euclidean/LogDet
#  is not found
# expt_dr assamese_female_english/all/budget_3500/target_20/FL2MI/39/budget_150/div_tf_idf_2gram_euclidean
#  is not found
# expt_dr assamese_female_english/all/budget_3500/target_20/FL2MI/39/budget_150/div_tf_idf_3gram_euclidean
#  is not found
# expt_dr assamese_female_english/all/budget_3500/target_20/FL2MI/39/budget_150/random
#  is not found
# run_1 missing kannada_male_english/all/budget_150/random/run_1
# run_2 missing kannada_male_english/all/budget_150/random/run_2
# run_3 missing kannada_male_english/all/budget_150/random/run_3
# expt_dr kannada_male_english/all/budget_3500/target_20/FL2MI/39/budget_150/div_tf_idf_2gram_euclidean/LogDet
#  is not found
# expt_dr kannada_male_english/all/budget_3500/target_20/FL2MI/39/budget_150/div_tf_idf_2gram_euclidean
#  is not found
# expt_dr kannada_male_english/all/budget_3500/target_20/FL2MI/39/budget_150/div_tf_idf_3gram_euclidean
#  is not found
# expt_dr kannada_male_english/all/budget_3500/target_20/FL2MI/39/budget_150/random
#  is not found
#        speaker ground      stage1  ft       stage2     duration WER-r1 WER-r2  \
# 0  assamese[F]    all  FL2MI 3500  39  uniform 150  739.0/739.0  19.81  19.63
# 1  assamese[F]    all   ~pretrain   -            -            -      -      -
# 2   kannada[M]    all  FL2MI 3500  39  uniform 150  683.8/739.3  13.66  13.39
# 3   kannada[M]    all   ~pretrain   -            -            -      -      -
#
#   WER-r3  WER-mean  WER-stdev                  distn_1  \
# 0  19.62     19.69      0.107             {'ass': 180}
# 1      -     27.05      0.000                        -
# 2  13.68     13.58      0.162  {'kan': 172, 'mal': 14}
# 3      -     18.74      0.000                        -
#
#                    distn_2                  distn_3
# 0             {'ass': 180}             {'ass': 180}
# 1                        -                        -
# 2  {'kan': 172, 'mal': 14}  {'kan': 172, 'mal': 14}
# 3                        -                        -

# %%
print(csv_name)
df.to_csv(csv_name, index=False)
# Out:
# unfmted_rpt_3500_20_39_150.csv

# %%
# sample_path = 'Error-Driven-ASR-Personalization/CMU_expts/speaker/hindi/manifests/TSS_output/all/budget_100/target_50/FL1MI/eta_1.0/euclidean/39/stats.txt'
# assamese_female_english/all/budget_2000/target_20/FL2MI/39/budget_200/error_model/run_1
# budget = 100


ft, b1, b2, t = '39', 2000, 250, 20
csv_name = "unfmted_rpt_{}_{}_{}_{}.csv".format(b1, t, ft, b2)

cols = ['speaker', 'ground', 'stage1', 'ft', 'stage2', 'duration',  
        'WER-r1', 'WER-r2', 'WER-r3', 'WER-mean', 'WER-stdev', 'distn_1', 'distn_2', 'distn_3']
df = pd.DataFrame(columns = cols)

speakers = ['assamese_female_english', 'gujarati_female_english', 'manipuri_female_english', 'hindi_male_english',
            'rajasthani_male_english', 'tamil_male_english', 'kannada_male_english', 'malayalam_male_english']
cnt = 0

speaker_pre_added={}
for speaker in speakers: 
    speaker_pre_added[speaker] = False

print(speakers)
for speaker in speakers:
    
    #starting with random
    pick_from = 'all'
    curr_dir = '{}/all/budget_{}/random'.format(speaker, b2)
    random_present = True
    for i in range(1,4):
        if not(pathlib.Path('{}/run_{}'.format(curr_dir, i)).is_dir()): 
            print("run_{} missing {}/run_{}".format(i, curr_dir, i))
            random_present = False
    if random_present:
        selection_stats = [accent_distribution('{}/run_{}/train.json'.format(curr_dir, i)) for i in range(1,4)]
        
        df_duration = time_fraction(curr_dir, speaker)
        df_samples = sample_fraction(curr_dir, speaker)
        try:
            wers = [WER_test_file('{}/run_{}/test_infer_log.txt'.format(curr_dir, i)) for i in range(1,4)]
            df_wer_mean = round(mean(wers), 2)
            df_wer_stdev = round(variance(wers)**0.5, 3)
        except:
            print("WER extraction failed ", curr_dir)
            wers = [0,0,0]
            df_wer_mean = 0
            df_wer_stdev = 999
#         if fun=='random': fun='rand'
        df = df.append(dict(zip(cols, [replace_with_short_forms(speaker), pick_from, 'rand {}'.format(b2), '-', '-', df_duration]+wers
                                +[df_wer_mean, df_wer_stdev] + selection_stats)), ignore_index=True)    
    #starting with TSS
#     for fun, method in itertools.product(['FL2MI', 'GCMI', 'LogDMI'], ['random', 'top', 'error_model']):
    for fun, method in itertools.product(['FL2MI'], ['random', 'top', 'error_model', 'div_tf_idf', 'w2v2_avg', 'true_wer', 'div_tf_idf_3gram_cosine']):
        if not(pathlib.Path('{}/{}/budget_{}/target_{}/{}/{}/budget_{}/{}'.format(speaker, pick_from, b1, t, 
                                                                               fun, ft, b2, method)).is_dir()):
            print('expt_dr {}/{}/budget_{}/target_{}/{}/{}/budget_{}/{}\n is not found'.format(speaker, pick_from, b1, t, fun, ft, b2, method))
            continue
        curr_dir = '{}/{}/budget_{}/target_{}/{}/{}/budget_{}/{}'.format(speaker, pick_from, b1, t, 
                                                                               fun, ft, b2, method)
        for i in range(1,4):
            if not(pathlib.Path('{}/run_{}'.format(curr_dir, i)).is_dir()): print("l28 run_{} missing {}/run_{}".format(i, curr_dir, i))
        selection_stats = [accent_distribution('{}/run_{}/train.json'.format(curr_dir, i)) for i in range(1,4)]
        
        df_duration = time_fraction(curr_dir, speaker)
        df_samples = sample_fraction(curr_dir, speaker)
        try:
            wers = [WER_test_file('{}/run_{}/test_infer_log.txt'.format(curr_dir, i)) for i in range(1,4)]
            df_wer_mean = round(mean(wers), 2)
            df_wer_stdev = round(variance(wers)**0.5, 3)
        except:
            continue
            print("WER extraction failed ", curr_dir)
            wers = [0,0,0]
            df_wer_mean = 0
            df_wer_stdev = 999
#         print(fun)
        if method=='error_model': method='error'
        if method=='true_wer': method='wer_skyline'
#         if method=='w2v2_avg': method='w2v2'
        if method=='random': method='rand'
        df = df.append(dict(zip(cols, [replace_with_short_forms(speaker), pick_from, "{} {}".format(fun,b1), 
                                       ft, "{} {}".format(method,b2), df_duration]+wers
                                +[df_wer_mean, df_wer_stdev] + selection_stats)), ignore_index=True)
        #pretrain vals
        if not(speaker_pre_added[speaker]):
            speaker_pre_added[speaker]=True
            df_wer_mean = WER_test_file('{}/TSS_output/pre_test_infer_log.txt'.format(speaker))
            df_wer_stdev = 0
            df = df.append(dict(zip(cols, [replace_with_short_forms(speaker), 'all', '~pretrain', '-', '-', '-', '-',  '-',  '-']
                                +[df_wer_mean, df_wer_stdev] + ['-',  '-',  '-'])), ignore_index=True)
    

# cols = ['speaker', 'ground', 'stage1', 'ft', 'stage2', 'duration', 'samples', 
#         'WER-r1', 'WER-r2', 'WER-r3', 'WER-mean', 'WER-stdev', 'distn_1', 'distn_2', 'distn_3']
custom_dict = {f'wer_skyline {b2}': 0, f'error {b2}': 1, f'top {b2}': 2, f'div_tf_idf {b2}': 3,  f'w2v2_avg {b2}': 4, 
               f'rand {b2}': 5, } 
df = df.sort_values(by=['stage2'], key=lambda x: x.map(custom_dict))
df = df.sort_values(by=['speaker', 'stage1', 'ft', 'ground'], ascending=[True, True, True, True], ignore_index=True)
# df = df.sort_values(by=['speaker', 'stage1', 'ft', 'ground', 'stage2'], ascending=[True, True, True, True, True], ignore_index=True)

display(df)
# Out:
# ['assamese_female_english', 'gujarati_female_english', 'manipuri_female_english', 'hindi_male_english', 'rajasthani_male_english', 'tamil_male_english', 'kannada_male_english', 'malayalam_male_english']
#           speaker ground      stage1  ft                       stage2  \
# 0     assamese[F]    all  FL2MI 2000  39              wer_skyline 250
# 1     assamese[F]    all  FL2MI 2000  39                    error 250
# 2     assamese[F]    all  FL2MI 2000  39                      top 250
# 3     assamese[F]    all  FL2MI 2000  39               div_tf_idf 250
# 4     assamese[F]    all  FL2MI 2000  39                 w2v2_avg 250
# 5     assamese[F]    all  FL2MI 2000  39                     rand 250
# 6     assamese[F]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 7     assamese[F]    all    rand 250   -                            -
# 8     assamese[F]    all   ~pretrain   -                            -
# 9     gujarati[F]    all  FL2MI 2000  39              wer_skyline 250
# 10    gujarati[F]    all  FL2MI 2000  39                    error 250
# 11    gujarati[F]    all  FL2MI 2000  39                      top 250
# 12    gujarati[F]    all  FL2MI 2000  39               div_tf_idf 250
# 13    gujarati[F]    all  FL2MI 2000  39                 w2v2_avg 250
# 14    gujarati[F]    all  FL2MI 2000  39                     rand 250
# 15    gujarati[F]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 16    gujarati[F]    all    rand 250   -                            -
# 17    gujarati[F]    all   ~pretrain   -                            -
# 18       hindi[M]    all  FL2MI 2000  39              wer_skyline 250
# 19       hindi[M]    all  FL2MI 2000  39                    error 250
# 20       hindi[M]    all  FL2MI 2000  39                      top 250
# 21       hindi[M]    all  FL2MI 2000  39               div_tf_idf 250
# 22       hindi[M]    all  FL2MI 2000  39                 w2v2_avg 250
# 23       hindi[M]    all  FL2MI 2000  39                     rand 250
# 24       hindi[M]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 25       hindi[M]    all    rand 250   -                            -
# 26       hindi[M]    all   ~pretrain   -                            -
# 27     kannada[M]    all  FL2MI 2000  39              wer_skyline 250
# 28     kannada[M]    all  FL2MI 2000  39                      top 250
# 29     kannada[M]    all  FL2MI 2000  39               div_tf_idf 250
# 30     kannada[M]    all  FL2MI 2000  39                 w2v2_avg 250
# 31     kannada[M]    all  FL2MI 2000  39                     rand 250
# 32     kannada[M]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 33     kannada[M]    all    rand 250   -                            -
# 34     kannada[M]    all   ~pretrain   -                            -
# 35   malayalam[M]    all  FL2MI 2000  39              wer_skyline 250
# 36   malayalam[M]    all  FL2MI 2000  39                    error 250
# 37   malayalam[M]    all  FL2MI 2000  39                      top 250
# 38   malayalam[M]    all  FL2MI 2000  39               div_tf_idf 250
# 39   malayalam[M]    all  FL2MI 2000  39                 w2v2_avg 250
# 40   malayalam[M]    all  FL2MI 2000  39                     rand 250
# 41   malayalam[M]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 42   malayalam[M]    all    rand 250   -                            -
# 43   malayalam[M]    all   ~pretrain   -                            -
# 44    manipuri[F]    all  FL2MI 2000  39              wer_skyline 250
# 45    manipuri[F]    all  FL2MI 2000  39                    error 250
# 46    manipuri[F]    all  FL2MI 2000  39                      top 250
# 47    manipuri[F]    all  FL2MI 2000  39               div_tf_idf 250
# 48    manipuri[F]    all  FL2MI 2000  39                 w2v2_avg 250
# 49    manipuri[F]    all  FL2MI 2000  39                     rand 250
# 50    manipuri[F]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 51    manipuri[F]    all    rand 250   -                            -
# 52    manipuri[F]    all   ~pretrain   -                            -
# 53  rajasthani[M]    all  FL2MI 2000  39              wer_skyline 250
# 54  rajasthani[M]    all  FL2MI 2000  39                    error 250
# 55  rajasthani[M]    all  FL2MI 2000  39                      top 250
# 56  rajasthani[M]    all  FL2MI 2000  39               div_tf_idf 250
# 57  rajasthani[M]    all  FL2MI 2000  39                 w2v2_avg 250
# 58  rajasthani[M]    all  FL2MI 2000  39                     rand 250
# 59  rajasthani[M]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 60  rajasthani[M]    all    rand 250   -                            -
# 61  rajasthani[M]    all   ~pretrain   -                            -
# 62       tamil[M]    all  FL2MI 2000  39              wer_skyline 250
# 63       tamil[M]    all  FL2MI 2000  39                    error 250
# 64       tamil[M]    all  FL2MI 2000  39                      top 250
# 65       tamil[M]    all  FL2MI 2000  39               div_tf_idf 250
# 66       tamil[M]    all  FL2MI 2000  39                 w2v2_avg 250
# 67       tamil[M]    all  FL2MI 2000  39                     rand 250
# 68       tamil[M]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 69       tamil[M]    all    rand 250   -                            -
# 70       tamil[M]    all   ~pretrain   -                            -
#
#          duration WER-r1 WER-r2 WER-r3  WER-mean  WER-stdev  \
# 0   1235.1/1235.1  17.65  17.66  17.46     17.59      0.113
# 1   1232.5/1232.5  17.76   17.8  18.64     18.07      0.497
# 2   1228.0/1228.0  18.51  18.45  18.79     18.58      0.181
# 3   1235.8/1235.8  18.77  18.78  19.01     18.85      0.136
# 4   1230.3/1230.3  18.13  18.01  18.08     18.07      0.060
# 5   1227.1/1227.1   18.3  18.91  18.46     18.56      0.316
# 6   1231.7/1231.7  18.87  19.01  18.52     18.80      0.252
# 7    201.6/1227.0  22.04  21.21  21.53     21.59      0.419
# 8               -      -      -      -     27.05      0.000
# 9   1232.7/1236.4   8.74   8.79   8.62      8.72      0.087
# 10  1236.3/1236.3   8.74    9.2   9.05      9.00      0.235
# 11  1224.4/1224.4   9.26   9.38   9.14      9.26      0.120
# 12  1232.5/1236.2   9.53   9.59    9.7      9.61      0.086
# 13  1232.8/1232.8    9.9   9.66   9.92      9.83      0.145
# 14  1223.4/1225.2   9.65   9.27   9.71      9.54      0.239
# 15  1237.3/1241.0   9.88   9.79   9.79      9.82      0.052
# 16   149.6/1227.0  10.84  11.09  10.46     10.80      0.317
# 17              -      -      -      -     13.73      0.000
# 18  1068.4/1231.8   8.02   7.79   7.92      7.91      0.115
# 19  1188.1/1231.9    8.3   7.83   7.87      8.00      0.261
# 20  1229.3/1229.3   9.37   9.14   9.15      9.22      0.130
# 21  1155.0/1232.0    8.7   8.76    8.7      8.72      0.035
# 22  1203.7/1232.5   8.11   8.25    8.1      8.15      0.084
# 23  1175.1/1227.2   8.28   8.09   8.74      8.37      0.334
# 24  1153.8/1230.7   8.13   8.16   8.16      8.15      0.017
# 25   112.1/1227.0   9.71   9.53   9.89      9.71      0.180
# 26              -      -      -      -     11.14      0.000
# 27  1217.7/1231.9  11.55  11.74  11.57     11.62      0.104
# 28  1228.2/1228.2   12.7  12.96   12.9     12.85      0.136
# 29  1220.3/1233.1  12.83  12.87  12.71     12.80      0.083
# 30  1225.7/1232.4  13.28  13.22  13.19     13.23      0.046
# 31  1220.8/1228.0  13.05  13.36  12.58     13.00      0.393
# 32  1224.1/1231.5  12.77   12.8  12.76     12.78      0.021
# 33   113.9/1227.0  15.67  15.28  16.05     15.67      0.385
# 34              -      -      -      -     18.74      0.000
# 35  1132.3/1230.6  13.32  13.41  13.25     13.33      0.080
# 36  1172.9/1232.5   13.2  13.45  14.25     13.63      0.548
# 37  1209.2/1226.1  13.73  13.79  13.72     13.75      0.038
# 38  1022.7/1234.9  14.25  14.22  14.25     14.24      0.017
# 39  1127.9/1232.9  14.05  13.98  13.96     14.00      0.047
# 40  1143.0/1227.7  14.18  13.92  14.36     14.15      0.221
# 41  1033.2/1231.8  13.94  14.03  14.01     13.99      0.047
# 42   132.3/1227.0  17.54  18.81  18.76     18.37      0.719
# 43              -      -      -      -     19.47      0.000
# 44  1233.4/1233.4  37.84  37.72  37.72     37.76      0.069
# 45  1219.1/1231.6  40.41  40.56  40.12     40.36      0.224
# 46  1226.6/1226.6  39.59  39.43  39.69     39.57      0.131
# 47  1208.5/1233.3  40.53  41.21  39.69     40.48      0.761
# 48  1230.5/1234.3  38.91   39.7  39.05     39.22      0.422
# 49  1220.8/1227.5   39.3  39.29  39.98     39.52      0.396
# 50  1213.2/1234.3  39.79  39.94  40.03     39.92      0.121
# 51   188.3/1227.0  44.46  45.05  42.25     43.92      1.476
# 52              -      -      -      -     53.11      0.000
# 53  1231.8/1231.8  15.36  13.88  15.38     14.87      0.860
# 54  1234.2/1234.2  13.69  14.13  14.92     14.25      0.623
# 55  1222.3/1222.3   14.4  14.41  14.43     14.41      0.015
# 56  1232.1/1232.1  15.02  14.91  14.92     14.95      0.061
# 57  1233.9/1233.9  14.58  14.76  14.77     14.70      0.107
# 58  1226.6/1226.6  14.73  14.53  15.47     14.91      0.495
# 59  1230.5/1230.5  14.76  14.83  14.81     14.80      0.036
# 60   126.2/1227.0  17.26  16.41  17.03     16.90      0.440
# 61              -      -      -      -     21.88      0.000
# 62  1232.4/1232.4  10.64  10.66  10.64     10.65      0.012
# 63  1233.0/1233.0  10.84  11.16  11.34     11.11      0.253
# 64  1223.1/1223.1  11.36  11.31  11.48     11.38      0.087
# 65  1231.9/1231.9  11.24  11.19  11.18     11.20      0.032
# 66  1234.8/1234.8  11.07  11.11  11.17     11.12      0.050
# 67  1225.2/1225.2  12.17   11.3  11.06     11.51      0.584
# 68  1234.3/1234.3  11.14  11.16  11.19     11.16      0.025
# 69   203.1/1227.0  11.89  11.89  12.03     11.94      0.081
# 70              -      -      -      -     12.58      0.000
#
#                                               distn_1  \
# 0                                        {'ass': 234}
# 1                                        {'ass': 235}
# 2                                        {'ass': 208}
# 3                                        {'ass': 221}
# 4                                        {'ass': 212}
# 5                                        {'ass': 227}
# 6                                        {'ass': 220}
# 7   {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 8                                                   -
# 9                              {'guj': 164, 'kan': 1}
# 10                                       {'guj': 153}
# 11                                       {'guj': 140}
# 12                             {'guj': 129, 'kan': 1}
# 13                                       {'guj': 136}
# 14                             {'guj': 158, 'kan': 1}
# 15                             {'guj': 131, 'kan': 1}
# 16  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 17                                                  -
# 18                  {'hin': 239, 'mal': 22, 'kan': 5}
# 19                   {'hin': 228, 'mal': 4, 'kan': 2}
# 20                                       {'hin': 248}
# 21                  {'hin': 194, 'mal': 11, 'kan': 1}
# 22                   {'hin': 202, 'mal': 4, 'kan': 1}
# 23                   {'hin': 230, 'mal': 6, 'kan': 1}
# 24                  {'hin': 193, 'mal': 11, 'kan': 1}
# 25  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 26                                                  -
# 27                             {'kan': 240, 'mal': 3}
# 28                                       {'kan': 201}
# 29                             {'kan': 181, 'mal': 3}
# 30                             {'kan': 188, 'mal': 3}
# 31                             {'kan': 206, 'mal': 1}
# 32                             {'kan': 180, 'mal': 2}
# 33  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 34                                                  -
# 35                  {'mal': 215, 'kan': 20, 'hin': 1}
# 36                   {'mal': 198, 'kan': 5, 'hin': 1}
# 37                   {'mal': 195, 'kan': 2, 'hin': 1}
# 38                  {'mal': 146, 'kan': 34, 'hin': 4}
# 39                  {'mal': 159, 'kan': 13, 'hin': 6}
# 40                  {'mal': 200, 'kan': 17, 'hin': 3}
# 41                  {'mal': 145, 'kan': 31, 'hin': 4}
# 42  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 43                                                  -
# 44                                       {'man': 341}
# 45                             {'man': 309, 'tam': 1}
# 46                                       {'man': 300}
# 47                             {'man': 305, 'tam': 5}
# 48                             {'man': 290, 'tam': 1}
# 49                             {'man': 308, 'tam': 1}
# 50                             {'man': 308, 'tam': 4}
# 51  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 52                                                  -
# 53                                       {'raj': 250}
# 54                                       {'raj': 197}
# 55                                       {'raj': 199}
# 56                                       {'raj': 193}
# 57                                       {'raj': 190}
# 58                                       {'raj': 214}
# 59                                       {'raj': 197}
# 60  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 61                                                  -
# 62                                       {'tam': 232}
# 63                                       {'tam': 207}
# 64                                       {'tam': 199}
# 65                                       {'tam': 191}
# 66                                       {'tam': 198}
# 67                                       {'tam': 218}
# 68                                       {'tam': 196}
# 69  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 70                                                  -
#
#                                               distn_2  \
# 0                                        {'ass': 234}
# 1                                        {'ass': 219}
# 2                                        {'ass': 208}
# 3                                        {'ass': 221}
# 4                                        {'ass': 212}
# 5                                        {'ass': 223}
# 6                                        {'ass': 220}
# 7   {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 8                                                   -
# 9                              {'guj': 164, 'kan': 1}
# 10                                       {'guj': 145}
# 11                                       {'guj': 140}
# 12                             {'guj': 129, 'kan': 1}
# 13                                       {'guj': 136}
# 14                                       {'guj': 150}
# 15                             {'guj': 131, 'kan': 1}
# 16  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 17                                                  -
# 18                  {'hin': 239, 'mal': 22, 'kan': 5}
# 19                   {'hin': 226, 'mal': 4, 'kan': 1}
# 20                                       {'hin': 248}
# 21                  {'hin': 194, 'mal': 11, 'kan': 1}
# 22                   {'hin': 202, 'mal': 4, 'kan': 1}
# 23                   {'hin': 245, 'mal': 4, 'kan': 2}
# 24                  {'hin': 193, 'mal': 11, 'kan': 1}
# 25  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 26                                                  -
# 27                             {'kan': 240, 'mal': 3}
# 28                                       {'kan': 201}
# 29                             {'kan': 181, 'mal': 3}
# 30                             {'kan': 188, 'mal': 3}
# 31                             {'kan': 197, 'mal': 3}
# 32                             {'kan': 180, 'mal': 2}
# 33  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 34                                                  -
# 35                  {'mal': 215, 'kan': 20, 'hin': 1}
# 36                  {'mal': 194, 'kan': 10, 'hin': 1}
# 37                   {'mal': 195, 'kan': 2, 'hin': 1}
# 38                  {'mal': 146, 'kan': 34, 'hin': 4}
# 39                  {'mal': 159, 'kan': 13, 'hin': 6}
# 40                  {'mal': 199, 'kan': 19, 'hin': 1}
# 41                  {'mal': 145, 'kan': 31, 'hin': 4}
# 42  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 43                                                  -
# 44                                       {'man': 341}
# 45                             {'man': 310, 'tam': 5}
# 46                                       {'man': 300}
# 47                             {'man': 305, 'tam': 5}
# 48                             {'man': 290, 'tam': 1}
# 49                             {'man': 309, 'tam': 2}
# 50                             {'man': 308, 'tam': 4}
# 51  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 52                                                  -
# 53                                       {'raj': 250}
# 54                                       {'raj': 205}
# 55                                       {'raj': 199}
# 56                                       {'raj': 193}
# 57                                       {'raj': 190}
# 58                                       {'raj': 214}
# 59                                       {'raj': 197}
# 60  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 61                                                  -
# 62                                       {'tam': 232}
# 63                                       {'tam': 202}
# 64                                       {'tam': 199}
# 65                                       {'tam': 191}
# 66                                       {'tam': 198}
# 67                                       {'tam': 213}
# 68                                       {'tam': 196}
# 69  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 70                                                  -
#
#                                               distn_3
# 0                                        {'ass': 234}
# 1                                        {'ass': 229}
# 2                                        {'ass': 208}
# 3                                        {'ass': 221}
# 4                                        {'ass': 212}
# 5                                        {'ass': 228}
# 6                                        {'ass': 220}
# 7   {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 8                                                   -
# 9                              {'guj': 164, 'kan': 1}
# 10                                       {'guj': 146}
# 11                                       {'guj': 140}
# 12                             {'guj': 129, 'kan': 1}
# 13                                       {'guj': 136}
# 14                                       {'guj': 153}
# 15                             {'guj': 131, 'kan': 1}
# 16  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 17                                                  -
# 18                  {'hin': 239, 'mal': 22, 'kan': 5}
# 19                             {'hin': 230, 'mal': 9}
# 20                                       {'hin': 248}
# 21                  {'hin': 194, 'mal': 11, 'kan': 1}
# 22                   {'hin': 202, 'mal': 4, 'kan': 1}
# 23                   {'hin': 226, 'mal': 9, 'kan': 2}
# 24                  {'hin': 193, 'mal': 11, 'kan': 1}
# 25  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 26                                                  -
# 27                             {'kan': 240, 'mal': 3}
# 28                                       {'kan': 201}
# 29                             {'kan': 181, 'mal': 3}
# 30                             {'kan': 188, 'mal': 3}
# 31                             {'kan': 203, 'mal': 2}
# 32                             {'kan': 180, 'mal': 2}
# 33  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 34                                                  -
# 35                  {'mal': 215, 'kan': 20, 'hin': 1}
# 36                  {'mal': 189, 'kan': 12, 'hin': 3}
# 37                   {'mal': 195, 'kan': 2, 'hin': 1}
# 38                  {'mal': 146, 'kan': 34, 'hin': 4}
# 39                  {'mal': 159, 'kan': 13, 'hin': 6}
# 40                            {'mal': 198, 'kan': 13}
# 41                  {'mal': 145, 'kan': 31, 'hin': 4}
# 42  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 43                                                  -
# 44                                       {'man': 341}
# 45                             {'man': 314, 'tam': 2}
# 46                                       {'man': 300}
# 47                             {'man': 305, 'tam': 5}
# 48                             {'man': 290, 'tam': 1}
# 49                             {'man': 305, 'tam': 2}
# 50                             {'man': 308, 'tam': 4}
# 51  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 52                                                  -
# 53                                       {'raj': 250}
# 54                                       {'raj': 212}
# 55                                       {'raj': 199}
# 56                                       {'raj': 193}
# 57                                       {'raj': 190}
# 58                                       {'raj': 205}
# 59                                       {'raj': 197}
# 60  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 61                                                  -
# 62                                       {'tam': 232}
# 63                                       {'tam': 207}
# 64                                       {'tam': 199}
# 65                                       {'tam': 191}
# 66                                       {'tam': 198}
# 67                                       {'tam': 217}
# 68                                       {'tam': 196}
# 69  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 70                                                  -

# %%
df.to_csv(csv_name, index=False)

# %% [markdown]
# ## Checking for CERS for once

# %%
ft, b1, b2, t = '39', 2000, 250, 20
csv_name = "unfmted_rpt_cer_{}_{}_{}_{}.csv".format(b1, t, ft, b2)

cols = ['speaker', 'ground', 'stage1', 'ft', 'stage2', 'duration',  
        'CER-r1', 'CER-r2', 'CER-r3', 'CER-mean', 'CER-stdev', 'distn_1', 'distn_2', 'distn_3']
df = pd.DataFrame(columns = cols)

speakers = ['assamese_female_english', 'gujarati_female_english', 'manipuri_female_english', 'hindi_male_english',
            'rajasthani_male_english', 'tamil_male_english', 'kannada_male_english', 'malayalam_male_english']
cnt = 0

speaker_pre_added={}
for speaker in speakers: 
    speaker_pre_added[speaker] = False

print(speakers)
for speaker in speakers:
    
    #starting with random
    pick_from = 'all'
    curr_dir = '{}/all/budget_{}/random'.format(speaker, b2)
    random_present = True
    for i in range(1,4):
        if not(pathlib.Path('{}/run_{}'.format(curr_dir, i)).is_dir()): 
            print("run_{} missing {}/run_{}".format(i, curr_dir, i))
            random_present = False
    if random_present:
        selection_stats = [accent_distribution('{}/run_{}/train.json'.format(curr_dir, i)) for i in range(1,4)]
        
        df_duration = time_fraction(curr_dir, speaker)
        df_samples = sample_fraction(curr_dir, speaker)
        try:
            cers = [CER_test_file('{}/run_{}/test_infer_log.txt'.format(curr_dir, i)) for i in range(1,4)]
            df_cer_mean = round(mean(cers), 2)
            df_cer_stdev = round(variance(cers)**0.5, 3)
        except:
            print("CER extraction failed ", curr_dir)
            cers = [0,0,0]
            df_cer_mean = 0
            df_cer_stdev = 999
#         if fun=='random': fun='rand'
        df = df.append(dict(zip(cols, [replace_with_short_forms(speaker), pick_from, 'rand {}'.format(b2), '-', '-', df_duration]+cers
                                +[df_cer_mean, df_cer_stdev] + selection_stats)), ignore_index=True)    
    #starting with TSS
#     for fun, method in itertools.product(['FL2MI', 'GCMI', 'LogDMI'], ['random', 'top', 'error_model']):
    for fun, method in itertools.product(['FL2MI'], ['random', 'top', 'error_model', 'div_tf_idf_3gram_cosine', 'w2v2_avg', 'true_wer']):
        if not(pathlib.Path('{}/{}/budget_{}/target_{}/{}/{}/budget_{}/{}'.format(speaker, pick_from, b1, t, 
                                                                               fun, ft, b2, method)).is_dir()):
            print('expt_dr {}/{}/budget_{}/target_{}/{}/{}/budget_{}/{}\n is not found'.format(speaker, pick_from, b1, t, fun, ft, b2, method))
            continue
        curr_dir = '{}/{}/budget_{}/target_{}/{}/{}/budget_{}/{}'.format(speaker, pick_from, b1, t, 
                                                                               fun, ft, b2, method)
        for i in range(1,4):
            if not(pathlib.Path('{}/run_{}'.format(curr_dir, i)).is_dir()): print("l28 run_{} missing {}/run_{}".format(i, curr_dir, i))
        selection_stats = [accent_distribution('{}/run_{}/train.json'.format(curr_dir, i)) for i in range(1,4)]
        
        df_duration = time_fraction(curr_dir, speaker)
        df_samples = sample_fraction(curr_dir, speaker)
        try:
            cers = [CER_test_file('{}/run_{}/test_infer_log.txt'.format(curr_dir, i)) for i in range(1,4)]
            df_cer_mean = round(mean(cers), 2)
            df_cer_stdev = round(variance(cers)**0.5, 3)
        except:
            continue
            print("CER extraction failed ", curr_dir)
            cers = [0,0,0]
            df_cer_mean = 0
            df_cer_stdev = 999
#         print(fun)
        if method=='error_model': method='error'
        if method=='true_wer': method='wer_skyline'
#         if method=='w2v2_avg': method='w2v2'
        if method=='random': method='rand'
        df = df.append(dict(zip(cols, [replace_with_short_forms(speaker), pick_from, "{} {}".format(fun,b1), 
                                       ft, "{} {}".format(method,b2), df_duration]+cers
                                +[df_cer_mean, df_cer_stdev] + selection_stats)), ignore_index=True)
        #pretrain vals
        if not(speaker_pre_added[speaker]):
            speaker_pre_added[speaker]=True
            df_cer_mean = CER_test_file('{}/TSS_output/pre_test_infer_log.txt'.format(speaker))
            df_cer_stdev = 0
            df = df.append(dict(zip(cols, [replace_with_short_forms(speaker), 'all', '~pretrain', '-', '-', '-', '-',  '-',  '-']
                                +[df_cer_mean, df_cer_stdev] + ['-',  '-',  '-'])), ignore_index=True)
    

# cols = ['speaker', 'ground', 'stage1', 'ft', 'stage2', 'duration', 'samples', 
#         'WER-r1', 'WER-r2', 'WER-r3', 'WER-mean', 'WER-stdev', 'distn_1', 'distn_2', 'distn_3']
custom_dict = {f'wer_skyline {b2}': 0, f'error {b2}': 1, f'top {b2}': 2, f'div_tf_idf {b2}': 3,  f'w2v2_avg {b2}': 4, 
               f'rand {b2}': 5, } 
df = df.sort_values(by=['stage2'], key=lambda x: x.map(custom_dict))
df = df.sort_values(by=['speaker', 'CER-mean', 'CER-stdev', 'stage1', 'ft', 'ground'], ascending=[True, True, True, True, True, True], ignore_index=True)
# df = df.sort_values(by=['speaker', 'stage1', 'ft', 'ground', 'stage2'], ascending=[True, True, True, True, True], ignore_index=True)

display(df)
# Out:
# ['assamese_female_english', 'gujarati_female_english', 'manipuri_female_english', 'hindi_male_english', 'rajasthani_male_english', 'tamil_male_english', 'kannada_male_english', 'malayalam_male_english']
#           speaker ground      stage1  ft                       stage2  \
# 0     assamese[F]    all  FL2MI 2000  39              wer_skyline 250
# 1     assamese[F]    all  FL2MI 2000  39                    error 250
# 2     assamese[F]    all  FL2MI 2000  39                 w2v2_avg 250
# 3     assamese[F]    all  FL2MI 2000  39                     rand 250
# 4     assamese[F]    all  FL2MI 2000  39                      top 250
# 5     assamese[F]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 6     assamese[F]    all    rand 250   -                            -
# 7     assamese[F]    all   ~pretrain   -                            -
# 8     gujarati[F]    all  FL2MI 2000  39              wer_skyline 250
# 9     gujarati[F]    all  FL2MI 2000  39                      top 250
# 10    gujarati[F]    all  FL2MI 2000  39                    error 250
# 11    gujarati[F]    all  FL2MI 2000  39                     rand 250
# 12    gujarati[F]    all  FL2MI 2000  39                 w2v2_avg 250
# 13    gujarati[F]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 14    gujarati[F]    all    rand 250   -                            -
# 15    gujarati[F]    all   ~pretrain   -                            -
# 16       hindi[M]    all  FL2MI 2000  39              wer_skyline 250
# 17       hindi[M]    all  FL2MI 2000  39                    error 250
# 18       hindi[M]    all  FL2MI 2000  39                 w2v2_avg 250
# 19       hindi[M]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 20       hindi[M]    all  FL2MI 2000  39                     rand 250
# 21       hindi[M]    all  FL2MI 2000  39                      top 250
# 22       hindi[M]    all    rand 250   -                            -
# 23       hindi[M]    all   ~pretrain   -                            -
# 24     kannada[M]    all  FL2MI 2000  39              wer_skyline 250
# 25     kannada[M]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 26     kannada[M]    all  FL2MI 2000  39                      top 250
# 27     kannada[M]    all  FL2MI 2000  39                     rand 250
# 28     kannada[M]    all  FL2MI 2000  39                 w2v2_avg 250
# 29     kannada[M]    all    rand 250   -                            -
# 30     kannada[M]    all   ~pretrain   -                            -
# 31   malayalam[M]    all  FL2MI 2000  39              wer_skyline 250
# 32   malayalam[M]    all  FL2MI 2000  39                    error 250
# 33   malayalam[M]    all  FL2MI 2000  39                      top 250
# 34   malayalam[M]    all  FL2MI 2000  39                 w2v2_avg 250
# 35   malayalam[M]    all  FL2MI 2000  39                     rand 250
# 36   malayalam[M]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 37   malayalam[M]    all    rand 250   -                            -
# 38   malayalam[M]    all   ~pretrain   -                            -
# 39    manipuri[F]    all  FL2MI 2000  39              wer_skyline 250
# 40    manipuri[F]    all  FL2MI 2000  39                 w2v2_avg 250
# 41    manipuri[F]    all  FL2MI 2000  39                     rand 250
# 42    manipuri[F]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 43    manipuri[F]    all  FL2MI 2000  39                      top 250
# 44    manipuri[F]    all  FL2MI 2000  39                    error 250
# 45    manipuri[F]    all    rand 250   -                            -
# 46    manipuri[F]    all   ~pretrain   -                            -
# 47  rajasthani[M]    all  FL2MI 2000  39                    error 250
# 48  rajasthani[M]    all  FL2MI 2000  39                      top 250
# 49  rajasthani[M]    all  FL2MI 2000  39              wer_skyline 250
# 50  rajasthani[M]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 51  rajasthani[M]    all  FL2MI 2000  39                 w2v2_avg 250
# 52  rajasthani[M]    all  FL2MI 2000  39                     rand 250
# 53  rajasthani[M]    all    rand 250   -                            -
# 54  rajasthani[M]    all   ~pretrain   -                            -
# 55       tamil[M]    all  FL2MI 2000  39              wer_skyline 250
# 56       tamil[M]    all  FL2MI 2000  39                    error 250
# 57       tamil[M]    all  FL2MI 2000  39  div_tf_idf_3gram_cosine 250
# 58       tamil[M]    all  FL2MI 2000  39                      top 250
# 59       tamil[M]    all  FL2MI 2000  39                 w2v2_avg 250
# 60       tamil[M]    all  FL2MI 2000  39                     rand 250
# 61       tamil[M]    all    rand 250   -                            -
# 62       tamil[M]    all   ~pretrain   -                            -
#
#          duration CER-r1 CER-r2 CER-r3  CER-mean  CER-stdev  \
# 0   1235.1/1235.1   6.63   6.63   6.55      6.60      0.046
# 1   1232.5/1232.5   6.53   6.62   7.13      6.76      0.324
# 2   1230.3/1230.3   6.82   6.89   6.76      6.82      0.065
# 3   1227.1/1227.1   6.84   7.24   6.72      6.93      0.272
# 4   1228.0/1228.0   7.06   6.99   7.19      7.08      0.101
# 5   1231.7/1231.7    7.2   7.26   6.98      7.15      0.147
# 6    201.6/1227.0   8.52   7.97   8.28      8.26      0.276
# 7               -      -      -      -     10.36      0.000
# 8   1232.7/1236.4   2.84    2.9   2.82      2.85      0.042
# 9   1224.4/1224.4   2.99   2.96   3.01      2.99      0.025
# 10  1236.3/1236.3   2.86   3.15   3.06      3.02      0.148
# 11  1223.4/1225.2   3.29   3.07   3.24      3.20      0.115
# 12  1232.8/1232.8   3.26   3.26   3.27      3.26      0.006
# 13  1237.3/1241.0   3.29   3.25   3.26      3.27      0.021
# 14   149.6/1227.0   3.85   3.82   3.64      3.77      0.114
# 15              -      -      -      -      4.90      0.000
# 16  1068.4/1231.8   2.41   2.32   2.38      2.37      0.046
# 17  1188.1/1231.9   2.56   2.34   2.44      2.45      0.110
# 18  1203.7/1232.5   2.42   2.51   2.45      2.46      0.046
# 19  1153.8/1230.7    2.5   2.52   2.49      2.50      0.015
# 20  1175.1/1227.2   2.58   2.42   2.74      2.58      0.160
# 21  1229.3/1229.3   3.06   2.96   2.96      2.99      0.058
# 22   112.1/1227.0    3.3   3.07   3.27      3.21      0.125
# 23              -      -      -      -      3.82      0.000
# 24  1217.7/1231.9   3.83   3.97   3.83      3.88      0.081
# 25  1224.1/1231.5   4.39   4.37   4.41      4.39      0.020
# 26  1228.2/1228.2   4.38   4.48   4.45      4.44      0.051
# 27  1220.8/1228.0   4.48   4.79   4.26      4.51      0.266
# 28  1225.7/1232.4   4.63   4.61   4.58      4.61      0.025
# 29   113.9/1227.0   6.17   5.52   6.09      5.93      0.354
# 30              -      -      -      -      7.50      0.000
# 31  1132.3/1230.6    4.3   4.34   4.31      4.32      0.021
# 32  1172.9/1232.5   4.36    4.5   4.76      4.54      0.203
# 33  1209.2/1226.1   4.63    4.7   4.63      4.65      0.040
# 34  1127.9/1232.9   4.77   4.71   4.74      4.74      0.030
# 35  1143.0/1227.7   4.82   4.75   4.75      4.77      0.040
# 36  1033.2/1231.8   4.78   4.82   4.76      4.79      0.031
# 37   132.3/1227.0   6.51   7.14   7.06      6.90      0.343
# 38              -      -      -      -      7.49      0.000
# 39  1233.4/1233.4  15.35  15.38  15.38     15.37      0.017
# 40  1230.5/1234.3  15.65  15.73  15.72     15.70      0.044
# 41  1220.8/1227.5  15.97  15.54  16.45     15.99      0.455
# 42  1213.2/1234.3  16.44  16.53  16.43     16.47      0.055
# 43  1226.6/1226.6  16.58  16.36  16.58     16.51      0.127
# 44  1219.1/1231.6   16.7  16.43   16.5     16.54      0.140
# 45   188.3/1227.0  18.31  18.63  17.58     18.17      0.538
# 46              -      -      -      -     21.92      0.000
# 47  1234.2/1234.2    4.5   4.83    5.1      4.81      0.300
# 48  1222.3/1222.3   4.87   4.88    4.9      4.88      0.015
# 49  1231.8/1231.8   5.17    4.5   5.13      4.93      0.376
# 50  1230.5/1230.5      5      5      5      5.00      0.000
# 51  1233.9/1233.9   4.97   5.06   5.06      5.03      0.052
# 52  1226.6/1226.6   5.12    4.9   5.37      5.13      0.235
# 53   126.2/1227.0   6.32   5.74   6.09      6.05      0.292
# 54              -      -      -      -      8.63      0.000
# 55  1232.4/1232.4   3.87   3.89   3.88      3.88      0.010
# 56  1233.0/1233.0   3.96   4.14   4.01      4.04      0.093
# 57  1234.3/1234.3   4.08   4.08   4.09      4.08      0.006
# 58  1223.1/1223.1   4.14   4.13   4.15      4.14      0.010
# 59  1234.8/1234.8   4.13   4.16   4.17      4.15      0.021
# 60  1225.2/1225.2   4.53   4.15   4.14      4.27      0.222
# 61   203.1/1227.0   4.46   4.46   4.53      4.48      0.040
# 62              -      -      -      -      4.75      0.000
#
#                                               distn_1  \
# 0                                        {'ass': 234}
# 1                                        {'ass': 235}
# 2                                        {'ass': 212}
# 3                                        {'ass': 227}
# 4                                        {'ass': 208}
# 5                                        {'ass': 220}
# 6   {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 7                                                   -
# 8                              {'guj': 164, 'kan': 1}
# 9                                        {'guj': 140}
# 10                                       {'guj': 153}
# 11                             {'guj': 158, 'kan': 1}
# 12                                       {'guj': 136}
# 13                             {'guj': 131, 'kan': 1}
# 14  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 15                                                  -
# 16                  {'hin': 239, 'mal': 22, 'kan': 5}
# 17                   {'hin': 228, 'mal': 4, 'kan': 2}
# 18                   {'hin': 202, 'mal': 4, 'kan': 1}
# 19                  {'hin': 193, 'mal': 11, 'kan': 1}
# 20                   {'hin': 230, 'mal': 6, 'kan': 1}
# 21                                       {'hin': 248}
# 22  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 23                                                  -
# 24                             {'kan': 240, 'mal': 3}
# 25                             {'kan': 180, 'mal': 2}
# 26                                       {'kan': 201}
# 27                             {'kan': 206, 'mal': 1}
# 28                             {'kan': 188, 'mal': 3}
# 29  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 30                                                  -
# 31                  {'mal': 215, 'kan': 20, 'hin': 1}
# 32                   {'mal': 198, 'kan': 5, 'hin': 1}
# 33                   {'mal': 195, 'kan': 2, 'hin': 1}
# 34                  {'mal': 159, 'kan': 13, 'hin': 6}
# 35                  {'mal': 200, 'kan': 17, 'hin': 3}
# 36                  {'mal': 145, 'kan': 31, 'hin': 4}
# 37  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 38                                                  -
# 39                                       {'man': 341}
# 40                             {'man': 290, 'tam': 1}
# 41                             {'man': 308, 'tam': 1}
# 42                             {'man': 308, 'tam': 4}
# 43                                       {'man': 300}
# 44                             {'man': 309, 'tam': 1}
# 45  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 46                                                  -
# 47                                       {'raj': 197}
# 48                                       {'raj': 199}
# 49                                       {'raj': 250}
# 50                                       {'raj': 197}
# 51                                       {'raj': 190}
# 52                                       {'raj': 214}
# 53  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 54                                                  -
# 55                                       {'tam': 232}
# 56                                       {'tam': 207}
# 57                                       {'tam': 196}
# 58                                       {'tam': 199}
# 59                                       {'tam': 198}
# 60                                       {'tam': 218}
# 61  {'man': 58, 'ass': 38, 'tam': 34, 'raj': 27, '...
# 62                                                  -
#
#                                               distn_2  \
# 0                                        {'ass': 234}
# 1                                        {'ass': 219}
# 2                                        {'ass': 212}
# 3                                        {'ass': 223}
# 4                                        {'ass': 208}
# 5                                        {'ass': 220}
# 6   {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 7                                                   -
# 8                              {'guj': 164, 'kan': 1}
# 9                                        {'guj': 140}
# 10                                       {'guj': 145}
# 11                                       {'guj': 150}
# 12                                       {'guj': 136}
# 13                             {'guj': 131, 'kan': 1}
# 14  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 15                                                  -
# 16                  {'hin': 239, 'mal': 22, 'kan': 5}
# 17                   {'hin': 226, 'mal': 4, 'kan': 1}
# 18                   {'hin': 202, 'mal': 4, 'kan': 1}
# 19                  {'hin': 193, 'mal': 11, 'kan': 1}
# 20                   {'hin': 245, 'mal': 4, 'kan': 2}
# 21                                       {'hin': 248}
# 22  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 23                                                  -
# 24                             {'kan': 240, 'mal': 3}
# 25                             {'kan': 180, 'mal': 2}
# 26                                       {'kan': 201}
# 27                             {'kan': 197, 'mal': 3}
# 28                             {'kan': 188, 'mal': 3}
# 29  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 30                                                  -
# 31                  {'mal': 215, 'kan': 20, 'hin': 1}
# 32                  {'mal': 194, 'kan': 10, 'hin': 1}
# 33                   {'mal': 195, 'kan': 2, 'hin': 1}
# 34                  {'mal': 159, 'kan': 13, 'hin': 6}
# 35                  {'mal': 199, 'kan': 19, 'hin': 1}
# 36                  {'mal': 145, 'kan': 31, 'hin': 4}
# 37  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 38                                                  -
# 39                                       {'man': 341}
# 40                             {'man': 290, 'tam': 1}
# 41                             {'man': 309, 'tam': 2}
# 42                             {'man': 308, 'tam': 4}
# 43                                       {'man': 300}
# 44                             {'man': 310, 'tam': 5}
# 45  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 46                                                  -
# 47                                       {'raj': 205}
# 48                                       {'raj': 199}
# 49                                       {'raj': 250}
# 50                                       {'raj': 197}
# 51                                       {'raj': 190}
# 52                                       {'raj': 214}
# 53  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 54                                                  -
# 55                                       {'tam': 232}
# 56                                       {'tam': 202}
# 57                                       {'tam': 196}
# 58                                       {'tam': 199}
# 59                                       {'tam': 198}
# 60                                       {'tam': 213}
# 61  {'ass': 48, 'tam': 42, 'man': 42, 'raj': 27, '...
# 62                                                  -
#
#                                               distn_3
# 0                                        {'ass': 234}
# 1                                        {'ass': 229}
# 2                                        {'ass': 212}
# 3                                        {'ass': 228}
# 4                                        {'ass': 208}
# 5                                        {'ass': 220}
# 6   {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 7                                                   -
# 8                              {'guj': 164, 'kan': 1}
# 9                                        {'guj': 140}
# 10                                       {'guj': 146}
# 11                                       {'guj': 153}
# 12                                       {'guj': 136}
# 13                             {'guj': 131, 'kan': 1}
# 14  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 15                                                  -
# 16                  {'hin': 239, 'mal': 22, 'kan': 5}
# 17                             {'hin': 230, 'mal': 9}
# 18                   {'hin': 202, 'mal': 4, 'kan': 1}
# 19                  {'hin': 193, 'mal': 11, 'kan': 1}
# 20                   {'hin': 226, 'mal': 9, 'kan': 2}
# 21                                       {'hin': 248}
# 22  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 23                                                  -
# 24                             {'kan': 240, 'mal': 3}
# 25                             {'kan': 180, 'mal': 2}
# 26                                       {'kan': 201}
# 27                             {'kan': 203, 'mal': 2}
# 28                             {'kan': 188, 'mal': 3}
# 29  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 30                                                  -
# 31                  {'mal': 215, 'kan': 20, 'hin': 1}
# 32                  {'mal': 189, 'kan': 12, 'hin': 3}
# 33                   {'mal': 195, 'kan': 2, 'hin': 1}
# 34                  {'mal': 159, 'kan': 13, 'hin': 6}
# 35                            {'mal': 198, 'kan': 13}
# 36                  {'mal': 145, 'kan': 31, 'hin': 4}
# 37  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 38                                                  -
# 39                                       {'man': 341}
# 40                             {'man': 290, 'tam': 1}
# 41                             {'man': 305, 'tam': 2}
# 42                             {'man': 308, 'tam': 4}
# 43                                       {'man': 300}
# 44                             {'man': 314, 'tam': 2}
# 45  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 46                                                  -
# 47                                       {'raj': 212}
# 48                                       {'raj': 199}
# 49                                       {'raj': 250}
# 50                                       {'raj': 197}
# 51                                       {'raj': 190}
# 52                                       {'raj': 205}
# 53  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 54                                                  -
# 55                                       {'tam': 232}
# 56                                       {'tam': 207}
# 57                                       {'tam': 196}
# 58                                       {'tam': 199}
# 59                                       {'tam': 198}
# 60                                       {'tam': 217}
# 61  {'man': 53, 'tam': 39, 'ass': 30, 'guj': 29, '...
# 62                                                  -
