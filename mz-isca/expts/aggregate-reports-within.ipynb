# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import re, os, csv, pathlib
import pandas as pd
from statistics import mean, variance
accents = ['african', 'indian', 'hongkong', 'philippines', 
           'england', 'scotland', 'ireland', 'australia', 
           'canada', 'us', 
           'bermuda', 'southatlandtic', 'wales', 'malaysia']
accent_short_forms = {'hongkong':'hk', "african":"afr", "philippines":"phil", "indian":"ind",  
                      "england":"eng", 'scotland':'sco', 'ireland':'ire',
                      "us":"us", "canada":"can", "australia":"aus",
                      'bermuda':'ber', 'southatlandtic':'satl', 'wales':'wal', 'malaysia':'mal'
                     }

def replace_with_short_forms(s):
    for key, value in accent_short_forms.items():
        s = s.replace(key, value)
    return s

def last_name(pth):
    return pathlib.PurePath(pth).name

def get_dirs(pth):
    return [last_name(f.name) for f in os.scandir(pth) if f.is_dir()]

def get_each_run(lne):
    return list(map(float, re.findall(': (.+?) -> ', lne)[0].split(' ')))

def get_selection_counts(s):
    return list(map(replace_with_short_forms, re.findall('Counter\\((.+?)\\)', s)))

def get_test_file_from_stats_path(run_number, stats_file_opened):
    return stats_file_opened.name[:-9]+"run_{}/output/test_infer_log.txt".format(run_number)

def WER_test_file(test_file):
    txt_file = open(test_file, 'r')
    lines = txt_file.readlines()
    matched = ""
    for line in lines:
        if "==========>>>>>>Evaluation Greedy WER: " in line:
            txt_file.close()
            return float(line.rstrip().split(": ")[1])
    txt_file.close()
    return ""

def get_eta(func, eta):
    if func != "FL1MI":
        return ""
    else:
        return "-n:"+str(float(eta[4:]))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
budget = 200
target = 20
features = 'wv10_100'
csv_name = "with_{}_{}_{}.csv".format(budget, target, features)

# %%
cols = ['accent', 'ground', 'function', 'feature', 'duration', 'samples', 
        'WER-r1', 'WER-r2', 'WER-r3', 'WER-mean', 'WER-var', 'accents_run1', 'accents_run2', 'accents_run3']
df = pd.DataFrame(columns = cols)

accents = ['african', 'indian', 'hongkong', 'philippines', 
           'england', 'scotland', 'ireland', 'australia', 
           'canada', 'us', 
           'bermuda', 'southatlandtic', 'wales', 'malaysia']

for accent in accents:
    if 'within' not in get_dirs('./{}/manifests/TSS_output/'.format(accent)):
        print("no within results for {}".format(accent))
        continue
    if not(pathlib.Path('./{}/manifests/TSS_output/within/budget_{}/target_{}/'.format(accent, budget, target)).is_dir()):
        continue
    for function in get_dirs('./{}/manifests/TSS_output/within/budget_{}/target_{}/'.format(accent, budget, target)):
        stats_file_path='./{}/manifests/TSS_output/within/budget_{}/target_{}/{}/stats.txt'.format(accent, budget, target, function)
        try:
            stats_file = open(stats_file_path, 'r')
        except:
            continue
        lines = stats_file.readlines()
        df_selections = get_selection_counts(lines[5])
        total_selections, total_durations, accented_selections, accented_durations = map(get_each_run, lines[:4])
        sample_frac = mean([x[0]/x[1] for x in zip(accented_selections, total_selections)])
        sample_total = mean(total_selections)
        duration_frac = mean([x[0]/x[1] for x in zip(accented_durations, total_durations)])
        duration_total = mean(total_durations)
        df_duration = "{:.2f}/{:.2f}".format(duration_total*duration_frac, duration_total)
        df_samples = "{:.2f}/{:.2f}".format(sample_total*sample_frac, sample_total)
        try:
            wers = [WER_test_file(get_test_file_from_stats_path(i, stats_file)) for i in range(1,4)]
            wer_floats = [x for x in wers if type(x)==float or type(x)==int]
            df_wer_mean = round(mean(wer_floats), 2)
            df_wer_var = round(variance(wer_floats), 3)
        except:
            print("no WER's in file", get_test_file_from_stats_path(1, stats_file))
#             continue
            wers = [0,0,0]
            df_wer_mean = 0
            df_wer_var = 999
        df = df.append(dict(zip(cols, [accent, "within", function, 
                        "NA", df_duration, df_samples]+ wers+[df_wer_mean, round(df_wer_var**0.5, 3)] + df_selections)), 
                       ignore_index=True)
        stats_file.close()

df = df.sort_values(by=['accent', 'feature', 'ground', 'function'], ascending=True, ignore_index=True)
display(df)
# Out:
# no WER's in file ./england/manifests/TSS_output/within/budget_200/target_20/self/run_1/output/test_infer_log.txt
# no WER's in file ./ireland/manifests/TSS_output/within/budget_200/target_20/self/run_1/output/test_infer_log.txt
# no WER's in file ./us/manifests/TSS_output/within/budget_200/target_20/self/run_1/output/test_infer_log.txt
#         accent  ground function feature         duration        samples  \
# 0      african  within     self      NA  1077.35/1077.35  218.67/218.67
# 1    australia  within     self      NA  1077.07/1077.07  219.33/219.33
# 2       canada  within     self      NA  1077.01/1077.01  210.33/210.33
# 3      england  within     self      NA  1076.67/1076.67  225.33/225.33
# 4     hongkong  within     self      NA  1076.20/1076.20  236.67/236.67
# 5       indian  within     self      NA  1075.37/1075.37  213.33/213.33
# 6      ireland  within     self      NA  1076.40/1076.40  227.33/227.33
# 7  philippines  within     self      NA  1078.76/1078.76  210.00/210.00
# 8     scotland  within     self      NA  1077.70/1077.70  198.67/198.67
# 9           us  within     self      NA  1078.19/1078.19  229.67/229.67
#
#    WER-r1  WER-r2  WER-r3  WER-mean  WER-var   accents_run1   accents_run2  \
# 0   21.69   23.28   22.41     22.46    0.796   {'afr': 220}   {'afr': 217}
# 1   25.52   27.01   25.76     26.10    0.800   {'aus': 216}   {'aus': 232}
# 2   16.69   16.73   16.86     16.76    0.089   {'can': 211}   {'can': 210}
# 3    0.00    0.00    0.00      0.00   31.607   {'eng': 219}   {'eng': 228}
# 4   29.24   28.33   28.39     28.65    0.509    {'hk': 239}    {'hk': 233}
# 5   38.32   38.14   38.19     38.22    0.095   {'ind': 215}   {'ind': 203}
# 6    0.00    0.00    0.00      0.00   31.607   {'ire': 229}   {'ire': 229}
# 7   28.45   29.38   28.77     28.87    0.472  {'phil': 211}  {'phil': 211}
# 8   45.00   45.74   45.52     45.42    0.379   {'sco': 205}   {'sco': 190}
# 9    0.00    0.00    0.00      0.00   31.607    {'us': 233}    {'us': 231}
#
#     accents_run3
# 0   {'afr': 219}
# 1   {'aus': 210}
# 2   {'can': 210}
# 3   {'eng': 229}
# 4    {'hk': 238}
# 5   {'ind': 222}
# 6   {'ire': 224}
# 7  {'phil': 208}
# 8   {'sco': 201}
# 9    {'us': 225}

# %%
# total selection : 100 100 100 -> 100.00
# total selection duration: 357.0149433106577 357.0149433106577 357.0149433106577 -> 357.01
# accented selection: 76 76 76 -> 76.00
# accented duration: 254.74947845804974 254.74947845804974 254.74947845804974 -> 254.75

# all selections: [Counter({'hindi': 76, 'korean': 8, 'spanish': 7, 'arabic': 3, 'chinese': 3, 'vietnamese': 3}), Counter({'hindi': 76, 'korean': 8, 'spanish': 7, 'arabic': 3, 'chinese': 3, 'vietnamese': 3}), Counter({'hindi': 76, 'korean': 8, 'spanish': 7, 'arabic': 3, 'chinese': 3, 'vietnamese': 3})]

#Evaluation Greedy WER: 16.19
df2 = pd.read_csv(csv_name)
print(csv_name)
df2=df2.append(df)
df2 = df2.sort_values(by=['accent', 'ground', 'feature', 'function'], ascending=True, ignore_index=True)
# df2.assign(accent = df['accent'].split('[')[1].split('/')[0] + df['two']**2).sort_values('accent')
display(df2)
# Out:
# with_200_20_wv10_100.csv
#             accent    ground function   feature         duration  \
# 0          african       all    FL2MI  wv10_100   960.90/1077.61
# 1          african       all     GCMI  wv10_100   948.66/1076.64
# 2          african       all   LogDMI  wv10_100   624.74/1077.02
# 3          african       all   random       NaN    42.57/1077.05
# 4          african  pretrain      NaN       NaN              NaN
# 5          african    within     self        NA  1077.35/1077.35
# 6        australia       all    FL2MI  wv10_100    24.30/1078.55
# 7        australia       all     GCMI  wv10_100   134.80/1077.38
# 8        australia       all   LogDMI  wv10_100   121.30/1077.17
# 9        australia       all   random       NaN    57.57/1077.05
# 10       australia  pretrain      NaN       NaN              NaN
# 11       australia    within     self        NA  1077.07/1077.07
# 12         bermuda       all    FL2MI  wv10_100     0.00/1074.73
# 13         bermuda       all     GCMI  wv10_100     0.00/1079.91
# 14         bermuda       all   LogDMI  wv10_100     0.00/1079.56
# 15         bermuda       all   random       NaN     0.00/1077.05
# 16         bermuda  pretrain      NaN       NaN              NaN
# 17          canada       all    FL2MI  wv10_100   168.36/1077.15
# 18          canada       all     GCMI  wv10_100   115.90/1076.79
# 19          canada       all   LogDMI  wv10_100   123.20/1076.80
# 20          canada       all   random       NaN    70.76/1077.05
# 21          canada  pretrain      NaN       NaN              NaN
# 22          canada    within     self        NA  1077.01/1077.01
# 23         england    within     self        NA  1076.67/1076.67
# 24        hongkong       all    FL2MI  wv10_100  1033.70/1078.40
# 25        hongkong       all     GCMI  wv10_100  1054.10/1077.16
# 26        hongkong       all   LogDMI  wv10_100   742.50/1073.06
# 27        hongkong       all   random       NaN    28.35/1077.05
# 28        hongkong  pretrain      NaN       NaN              NaN
# 29        hongkong    within     self        NA  1076.20/1076.20
# 30          indian       all    FL2MI  wv10_100  1038.24/1077.44
# 31          indian       all     GCMI  wv10_100  1038.78/1079.16
# 32          indian       all   LogDMI  wv10_100   614.18/1078.80
# 33          indian       all   random       NaN   149.59/1077.05
# 34          indian  pretrain      NaN       NaN              NaN
# 35          indian    within     self        NA  1075.37/1075.37
# 36         ireland    within     self        NA  1076.40/1076.40
# 37        malaysia       all    FL2MI  wv10_100     0.00/1079.64
# 38        malaysia       all     GCMI  wv10_100     0.00/1075.00
# 39        malaysia       all   LogDMI  wv10_100     0.00/1074.77
# 40        malaysia       all   random       NaN     0.00/1077.05
# 41        malaysia  pretrain      NaN       NaN              NaN
# 42     philippines       all    FL2MI  wv10_100  1059.26/1078.86
# 43     philippines       all     GCMI  wv10_100  1073.38/1079.48
# 44     philippines       all   LogDMI  wv10_100   669.90/1079.30
# 45     philippines       all   random       NaN    38.64/1077.05
# 46     philippines  pretrain      NaN       NaN              NaN
# 47     philippines    within     self        NA  1078.76/1078.76
# 48        scotland       all    FL2MI  wv10_100  1061.10/1076.60
# 49        scotland       all     GCMI  wv10_100  1074.00/1076.50
# 50        scotland       all   LogDMI  wv10_100   720.90/1072.90
# 51        scotland       all   random       NaN    51.41/1077.05
# 52        scotland  pretrain      NaN       NaN              NaN
# 53        scotland    within     self        NA  1077.70/1077.70
# 54  southatlandtic       all    FL2MI  wv10_100     0.00/1079.45
# 55  southatlandtic       all     GCMI  wv10_100     0.00/1076.45
# 56  southatlandtic       all   LogDMI  wv10_100     0.00/1073.25
# 57  southatlandtic  pretrain      NaN       NaN              NaN
# 58              us    within     self        NA  1078.19/1078.19
#
#           samples WER-r1 WER-r2 WER-r3  WER-mean  WER-var  \
# 0   178.00/204.00   22.5   22.6  22.54     22.55    0.003
# 1   175.00/199.00  23.34   22.0  22.43     22.59    0.468
# 2   123.00/224.00  22.64  22.23  22.74     22.54    0.073
# 3     7.69/228.00  23.07  23.67  22.93     23.22    0.155
# 4             NaN      -      -      -     23.75      NaN
# 5   218.67/218.67  21.69  23.28  22.41     22.46    0.796
# 6     6.00/239.00  28.99  28.99  28.99     28.99    0.000
# 7    27.00/225.00  26.99  26.75  26.71     26.82    0.023
# 8    25.00/233.00  28.54  28.11  27.57     28.07    0.236
# 9    12.01/228.00  28.52  27.87  27.68     28.02    0.194
# 10            NaN      -      -      -     28.76      NaN
# 11  219.33/219.33  25.52  27.01  25.76     26.10    0.800
# 12    0.00/225.00  23.68  23.71  23.86     23.75    0.009
# 13    0.00/224.00  23.22  23.63  23.58     23.48    0.050
# 14    0.00/228.00  23.68   23.3   23.4     23.46    0.039
# 15    0.00/228.00  24.02  24.22  24.22     24.15    0.013
# 16            NaN      -      -      -     23.91      NaN
# 17   33.00/221.00  16.89  16.95  16.89     16.91    0.001
# 18   20.00/206.00  16.55  16.58   16.9     16.68    0.038
# 19   24.00/227.00  16.69  16.96  17.11     16.92    0.045
# 20   14.24/228.00  16.66  17.08  16.66     16.80    0.059
# 21            NaN      -      -      -     16.79      NaN
# 22  210.33/210.33  16.69  16.73  16.86     16.76    0.089
# 23  225.33/225.33    0.0    0.0    0.0      0.00   31.607
# 24  210.00/219.00  28.41  28.74  28.65     28.60    0.029
# 25  211.00/215.00   29.1  29.54  29.01     29.22    0.080
# 26  152.00/224.00  30.67  30.25  29.93     30.28    0.138
# 27    5.65/228.00  32.21  31.76  31.97     31.98    0.051
# 28            NaN      -      -      -     32.15      NaN
# 29  236.67/236.67  29.24  28.33  28.39     28.65    0.509
# 30  195.00/203.00  38.93  38.29  38.06     38.43    0.203
# 31  187.00/194.00  38.37  38.35  38.14     38.29    0.016
# 32  127.00/223.00  39.09  39.04  38.85     38.99    0.016
# 33   30.66/228.00   40.4  41.55  40.62     40.86    0.373
# 34            NaN      -      -      -     43.73      NaN
# 35  213.33/213.33  38.32  38.14  38.19     38.22    0.095
# 36  227.33/227.33    0.0    0.0    0.0      0.00   31.607
# 37    0.00/221.00  34.58  34.69  34.64     34.64    0.003
# 38    0.00/226.00  33.78  33.42  34.09     33.76    0.112
# 39    0.00/243.00  34.27  34.09   34.4     34.25    0.024
# 40    0.00/228.00  34.58   34.9  35.28     34.92    0.123
# 41            NaN      -      -      -     35.59      NaN
# 42  194.00/199.00  29.35  29.12  29.38     29.28    0.020
# 43  195.00/196.00  29.44  29.29  29.16     29.30    0.020
# 44  124.00/213.00  29.12  28.87  28.75     28.91    0.036
# 45    6.98/228.00  29.42  29.96  30.11     29.83    0.132
# 46            NaN      -      -      -     30.45      NaN
# 47  210.00/210.00  28.45  29.38  28.77     28.87    0.472
# 48  158.00/161.00  46.15  46.27   46.5     46.31    0.032
# 49  173.00/174.00  46.36  46.38  46.23     46.32    0.007
# 50  124.00/193.00  46.27  46.44  46.54     46.42    0.019
# 51   10.66/228.00  51.19  49.39  49.63     50.07    0.955
# 52            NaN      -      -      -     51.72      NaN
# 53  198.67/198.67   45.0  45.74  45.52     45.42    0.379
# 54    0.00/209.00  25.32  25.96  26.14     25.81    0.186
# 55    0.00/229.00  25.87  26.78  26.33     26.33    0.207
# 56    0.00/233.00  25.14  24.04  24.22     24.47    0.348
# 57            NaN      -      -      -     24.31      NaN
# 58  229.67/229.67    0.0    0.0    0.0      0.00   31.607
#
#                                         accents-run_1  \
# 0   {'afr': 178, 'eng': 9, 'us': 7, 'aus': 7, 'ind...
# 1   {'afr': 175, 'aus': 9, 'us': 8, 'eng': 6, 'ind...
# 2   {'afr': 123, 'eng': 36, 'us': 31, 'aus': 15, '...
# 3   {'us': 91, 'eng': 47, 'ind': 27, 'can': 14, 'a...
# 4                                                 NaN
# 5                                                 NaN
# 6   {'us': 178, 'eng': 33, 'can': 16, 'aus': 6, 'a...
# 7   {'us': 107, 'eng': 61, 'aus': 27, 'can': 13, '...
# 8   {'us': 85, 'eng': 71, 'aus': 25, 'afr': 17, 'i...
# 9   {'us': 91, 'eng': 47, 'ind': 27, 'can': 14, 'a...
# 10                                                NaN
# 11                                                NaN
# 12  {'us': 90, 'ind': 59, 'phil': 47, 'can': 13, '...
# 13  {'us': 112, 'eng': 46, 'aus': 23, 'ind': 17, '...
# 14  {'us': 76, 'ind': 40, 'eng': 29, 'phil': 21, '...
# 15  {'us': 91, 'eng': 47, 'ind': 27, 'can': 14, 'a...
# 16                                                NaN
# 17  {'us': 183, 'can': 33, 'sco': 2, 'hk': 1, 'afr...
# 18         {'us': 180, 'can': 20, 'aus': 4, 'eng': 2}
# 19  {'us': 126, 'sco': 24, 'can': 24, 'hk': 23, 'a...
# 20  {'us': 91, 'eng': 47, 'ind': 27, 'can': 14, 'a...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24           {'hk': 210, 'us': 5, 'eng': 2, 'ind': 2}
# 25           {'hk': 211, 'aus': 2, 'us': 1, 'afr': 1}
# 26  {'hk': 152, 'us': 37, 'eng': 15, 'ind': 8, 'ca...
# 27  {'us': 91, 'eng': 47, 'ind': 27, 'can': 14, 'a...
# 28                                                NaN
# 29                                                NaN
# 30  {'ind': 195, 'us': 4, 'eng': 2, 'can': 1, 'hk'...
# 31  {'ind': 187, 'us': 3, 'aus': 2, 'afr': 1, 'eng...
# 32  {'ind': 127, 'us': 49, 'eng': 18, 'aus': 10, '...
# 33  {'us': 91, 'eng': 47, 'ind': 27, 'can': 14, 'a...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  {'ind': 123, 'us': 42, 'eng': 33, 'aus': 12, '...
# 38  {'us': 87, 'eng': 56, 'aus': 30, 'ind': 23, 'c...
# 39  {'eng': 64, 'us': 60, 'ind': 53, 'hk': 19, 'au...
# 40  {'us': 91, 'eng': 47, 'ind': 27, 'can': 14, 'a...
# 41                                                NaN
# 42          {'phil': 194, 'us': 3, 'hk': 1, 'eng': 1}
# 43                             {'phil': 195, 'us': 1}
# 44  {'phil': 124, 'us': 43, 'hk': 14, 'ind': 12, '...
# 45  {'us': 91, 'eng': 47, 'ind': 27, 'can': 14, 'a...
# 46                                                NaN
# 47                                                NaN
# 48                    {'sco': 158, 'eng': 2, 'hk': 1}
# 49                             {'sco': 173, 'eng': 1}
# 50  {'sco': 124, 'eng': 45, 'hk': 11, 'us': 4, 'ir...
# 51  {'us': 91, 'eng': 47, 'ind': 27, 'can': 14, 'a...
# 52                                                NaN
# 53                                                NaN
# 54  {'eng': 139, 'us': 41, 'aus': 13, 'can': 9, 'i...
# 55  {'us': 107, 'eng': 66, 'aus': 28, 'can': 16, '...
# 56  {'eng': 62, 'us': 56, 'aus': 33, 'ind': 32, 'a...
# 57                                                NaN
# 58                                                NaN
#
#                                         accents-run_2  \
# 0   {'afr': 178, 'eng': 9, 'us': 7, 'aus': 7, 'ind...
# 1   {'afr': 175, 'aus': 9, 'us': 8, 'eng': 6, 'ind...
# 2   {'afr': 123, 'eng': 36, 'us': 31, 'aus': 15, '...
# 3   {'us': 94, 'eng': 37, 'ind': 31, 'aus': 12, 's...
# 4                                                 NaN
# 5                                                 NaN
# 6   {'us': 178, 'eng': 33, 'can': 16, 'aus': 6, 'a...
# 7   {'us': 107, 'eng': 61, 'aus': 27, 'can': 13, '...
# 8   {'us': 85, 'eng': 71, 'aus': 25, 'afr': 17, 'i...
# 9   {'us': 94, 'eng': 37, 'ind': 31, 'aus': 12, 's...
# 10                                                NaN
# 11                                                NaN
# 12  {'us': 90, 'ind': 59, 'phil': 47, 'can': 13, '...
# 13  {'us': 112, 'eng': 46, 'aus': 23, 'ind': 17, '...
# 14  {'us': 76, 'ind': 40, 'eng': 29, 'phil': 21, '...
# 15  {'us': 94, 'eng': 37, 'ind': 31, 'aus': 12, 's...
# 16                                                NaN
# 17  {'us': 183, 'can': 33, 'sco': 2, 'hk': 1, 'afr...
# 18         {'us': 180, 'can': 20, 'aus': 4, 'eng': 2}
# 19  {'us': 126, 'sco': 24, 'can': 24, 'hk': 23, 'a...
# 20  {'us': 94, 'eng': 37, 'ind': 31, 'aus': 12, 's...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24           {'hk': 210, 'us': 5, 'eng': 2, 'ind': 2}
# 25           {'hk': 211, 'aus': 2, 'us': 1, 'afr': 1}
# 26  {'hk': 152, 'us': 37, 'eng': 15, 'ind': 8, 'ca...
# 27  {'us': 94, 'eng': 37, 'ind': 31, 'aus': 12, 's...
# 28                                                NaN
# 29                                                NaN
# 30  {'ind': 195, 'us': 4, 'eng': 2, 'can': 1, 'hk'...
# 31  {'ind': 187, 'us': 3, 'aus': 2, 'afr': 1, 'eng...
# 32  {'ind': 127, 'us': 49, 'eng': 18, 'aus': 10, '...
# 33  {'us': 94, 'eng': 37, 'ind': 31, 'aus': 12, 's...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  {'ind': 123, 'us': 42, 'eng': 33, 'aus': 12, '...
# 38  {'us': 87, 'eng': 56, 'aus': 30, 'ind': 23, 'c...
# 39  {'eng': 64, 'us': 60, 'ind': 53, 'hk': 19, 'au...
# 40  {'us': 94, 'eng': 37, 'ind': 31, 'aus': 12, 's...
# 41                                                NaN
# 42          {'phil': 194, 'us': 3, 'hk': 1, 'eng': 1}
# 43                             {'phil': 195, 'us': 1}
# 44  {'phil': 124, 'us': 43, 'hk': 14, 'ind': 12, '...
# 45  {'us': 94, 'eng': 37, 'ind': 31, 'aus': 12, 's...
# 46                                                NaN
# 47                                                NaN
# 48                    {'sco': 158, 'eng': 2, 'hk': 1}
# 49                             {'sco': 173, 'eng': 1}
# 50  {'sco': 124, 'eng': 45, 'hk': 11, 'us': 4, 'ir...
# 51  {'us': 94, 'eng': 37, 'ind': 31, 'aus': 12, 's...
# 52                                                NaN
# 53                                                NaN
# 54  {'eng': 139, 'us': 41, 'aus': 13, 'can': 9, 'i...
# 55  {'us': 107, 'eng': 66, 'aus': 28, 'can': 16, '...
# 56  {'eng': 62, 'us': 56, 'aus': 33, 'ind': 32, 'a...
# 57                                                NaN
# 58                                                NaN
#
#                                         accents-run_3   accents_run1  \
# 0   {'afr': 178, 'eng': 9, 'us': 7, 'aus': 7, 'ind...            NaN
# 1   {'afr': 175, 'aus': 9, 'us': 8, 'eng': 6, 'ind...            NaN
# 2   {'afr': 123, 'eng': 36, 'us': 31, 'aus': 15, '...            NaN
# 3   {'us': 94, 'ind': 34, 'eng': 31, 'can': 20, 's...            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN   {'afr': 220}
# 6   {'us': 178, 'eng': 33, 'can': 16, 'aus': 6, 'a...            NaN
# 7   {'us': 107, 'eng': 61, 'aus': 27, 'can': 13, '...            NaN
# 8   {'us': 85, 'eng': 71, 'aus': 25, 'afr': 17, 'i...            NaN
# 9   {'us': 94, 'ind': 34, 'eng': 31, 'can': 20, 's...            NaN
# 10                                                NaN            NaN
# 11                                                NaN   {'aus': 216}
# 12  {'us': 90, 'ind': 59, 'phil': 47, 'can': 13, '...            NaN
# 13  {'us': 112, 'eng': 46, 'aus': 23, 'ind': 17, '...            NaN
# 14  {'us': 76, 'ind': 40, 'eng': 29, 'phil': 21, '...            NaN
# 15  {'us': 94, 'ind': 34, 'eng': 31, 'can': 20, 's...            NaN
# 16                                                NaN            NaN
# 17  {'us': 183, 'can': 33, 'sco': 2, 'hk': 1, 'afr...            NaN
# 18         {'us': 180, 'can': 20, 'aus': 4, 'eng': 2}            NaN
# 19  {'us': 126, 'sco': 24, 'can': 24, 'hk': 23, 'a...            NaN
# 20  {'us': 94, 'ind': 34, 'eng': 31, 'can': 20, 's...            NaN
# 21                                                NaN            NaN
# 22                                                NaN   {'can': 211}
# 23                                                NaN   {'eng': 219}
# 24           {'hk': 210, 'us': 5, 'eng': 2, 'ind': 2}            NaN
# 25           {'hk': 211, 'aus': 2, 'us': 1, 'afr': 1}            NaN
# 26  {'hk': 152, 'us': 37, 'eng': 15, 'ind': 8, 'ca...            NaN
# 27  {'us': 94, 'ind': 34, 'eng': 31, 'can': 20, 's...            NaN
# 28                                                NaN            NaN
# 29                                                NaN    {'hk': 239}
# 30  {'ind': 195, 'us': 4, 'eng': 2, 'can': 1, 'hk'...            NaN
# 31  {'ind': 187, 'us': 3, 'aus': 2, 'afr': 1, 'eng...            NaN
# 32  {'ind': 127, 'us': 49, 'eng': 18, 'aus': 10, '...            NaN
# 33  {'us': 94, 'ind': 34, 'eng': 31, 'can': 20, 's...            NaN
# 34                                                NaN            NaN
# 35                                                NaN   {'ind': 215}
# 36                                                NaN   {'ire': 229}
# 37  {'ind': 123, 'us': 42, 'eng': 33, 'aus': 12, '...            NaN
# 38  {'us': 87, 'eng': 56, 'aus': 30, 'ind': 23, 'c...            NaN
# 39  {'eng': 64, 'us': 60, 'ind': 53, 'hk': 19, 'au...            NaN
# 40  {'us': 94, 'ind': 34, 'eng': 31, 'can': 20, 's...            NaN
# 41                                                NaN            NaN
# 42          {'phil': 194, 'us': 3, 'hk': 1, 'eng': 1}            NaN
# 43                             {'phil': 195, 'us': 1}            NaN
# 44  {'phil': 124, 'us': 43, 'hk': 14, 'ind': 12, '...            NaN
# 45  {'us': 94, 'ind': 34, 'eng': 31, 'can': 20, 's...            NaN
# 46                                                NaN            NaN
# 47                                                NaN  {'phil': 211}
# 48                    {'sco': 158, 'eng': 2, 'hk': 1}            NaN
# 49                             {'sco': 173, 'eng': 1}            NaN
# 50  {'sco': 124, 'eng': 45, 'hk': 11, 'us': 4, 'ir...            NaN
# 51  {'us': 94, 'ind': 34, 'eng': 31, 'can': 20, 's...            NaN
# 52                                                NaN            NaN
# 53                                                NaN   {'sco': 205}
# 54  {'eng': 139, 'us': 41, 'aus': 13, 'can': 9, 'i...            NaN
# 55  {'us': 107, 'eng': 66, 'aus': 28, 'can': 16, '...            NaN
# 56  {'eng': 62, 'us': 56, 'aus': 33, 'ind': 32, 'a...            NaN
# 57                                                NaN            NaN
# 58                                                NaN    {'us': 233}
#
#      accents_run2   accents_run3
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN
# 5    {'afr': 217}   {'afr': 219}
# 6             NaN            NaN
# 7             NaN            NaN
# 8             NaN            NaN
# 9             NaN            NaN
# 10            NaN            NaN
# 11   {'aus': 232}   {'aus': 210}
# 12            NaN            NaN
# 13            NaN            NaN
# 14            NaN            NaN
# 15            NaN            NaN
# 16            NaN            NaN
# 17            NaN            NaN
# 18            NaN            NaN
# 19            NaN            NaN
# 20            NaN            NaN
# 21            NaN            NaN
# 22   {'can': 210}   {'can': 210}
# 23   {'eng': 228}   {'eng': 229}
# 24            NaN            NaN
# 25            NaN            NaN
# 26            NaN            NaN
# 27            NaN            NaN
# 28            NaN            NaN
# 29    {'hk': 233}    {'hk': 238}
# 30            NaN            NaN
# 31            NaN            NaN
# 32            NaN            NaN
# 33            NaN            NaN
# 34            NaN            NaN
# 35   {'ind': 203}   {'ind': 222}
# 36   {'ire': 229}   {'ire': 224}
# 37            NaN            NaN
# 38            NaN            NaN
# 39            NaN            NaN
# 40            NaN            NaN
# 41            NaN            NaN
# 42            NaN            NaN
# 43            NaN            NaN
# 44            NaN            NaN
# 45            NaN            NaN
# 46            NaN            NaN
# 47  {'phil': 211}  {'phil': 208}
# 48            NaN            NaN
# 49            NaN            NaN
# 50            NaN            NaN
# 51            NaN            NaN
# 52            NaN            NaN
# 53   {'sco': 190}   {'sco': 201}
# 54            NaN            NaN
# 55            NaN            NaN
# 56            NaN            NaN
# 57            NaN            NaN
# 58    {'us': 231}    {'us': 225}

# %%
df2.to_csv(csv_name, index=False)
# input_file = csv.DictReader(open(csv_name))
